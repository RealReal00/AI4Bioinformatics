# %% [markdown]
# # LAB: Multimodal Learning WSI + Genomics
# Authors:
# - Vittorio Pipoli (vittorio.pipoli@unimore.it)
# - Francesca Miccolis (francesca.miccolis@unimore.it)
#
# ### Assignment Goals
# 1. Familiarity with the “Survival Prediction from WSI and Genomics” task
# 2. Familiarity with multimodal architectures
# 3. Implementation of a customised model for “Survival Prediction from WSI and Genomics”
#
# ### References
# 1. ABMIL (paper: https://proceedings.mlr.press/v80/ilse18a/ilse18a.pdf)
# 3. MCAT (paper: https://openaccess.thecvf.com/content/ICCV2021/papers/Chen_Multimodal_Co-Attention_Transformer_for_Survival_Prediction_in_Gigapixel_Whole_Slide_ICCV_2021_paper.pdf)
# 2. SurvPath (paper: https://openaccess.thecvf.com/content/CVPR2024/papers/Jaume_Modeling_Dense_Multimodal_Interactions_Between_Biological_Pathways_and_Histology_for_CVPR_2024_paper.pdf)

# %% [markdown]
# ### install missing packages

# %%
# !pip install pytorch_model_summary
# !pip install munch
# !pip install scikit-survival
# !pip install lifelines

# %% [markdown]
# ### import packages

# %%
import os
import torch
from torch import nn
import torch.optim as optim
from torch.backends import cudnn
import torch.nn.init as init
from pytorch_model_summary import summary
import torch.nn.functional as F
import numpy as np
import pandas as pd
from torch.utils.data import Dataset, DataLoader, Subset
import time
import logging
from tqdm import tqdm
import math
from scipy import stats
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
from munch import Munch
from sksurv.metrics import concordance_index_censored
from copy import deepcopy
from sklearn.preprocessing import StandardScaler
from lifelines import KaplanMeierFitter
from sklearn.metrics import roc_auc_score, confusion_matrix, f1_score
import random
from lifelines.statistics import logrank_test

# %%
def setup(seed):
    os.environ['PYTHONHASHSEED'] = str(seed)
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)  # If using CUDA.
    torch.cuda.manual_seed_all(seed)  # If using multi-GPU.
    torch.backends.cudnn.benchmark = False
    torch.backends.cudnn.deterministic = True
### Fix random seed for reproducibility (Try different random seeds)
SEED = 42
setup(SEED)

# %% [markdown]
# # Download Multimodal Survival Dataset (TCGA BRCA)

# %% [markdown]
# ### downaload takes approx. 10 to 20 minutes...

# %%
# Choose one of the two and comment the other one.
# OneDrive seems to be the faster.

# Download from UNIMORE
# !wget https://ailb-web.ing.unimore.it/publicfiles/AIforBio/small/LAB_WSI_Genomics.zip

# Download from OneDrive
# !wget -O LAB_WSI_Genomics.zip "https://unimore365-my.sharepoint.com/:u:/g/personal/vpipoli_unimore_it/EZakt73hnBJGng4OCqCpFaQBULa4HU5FCz8aNxE-0z87_w?e=tvB5ep&download=1"

# %%
# !wget -O LAB_WSI_Genomics.zip "https://unimore365-my.sharepoint.com/:u:/g/personal/vpipoli_unimore_it/EZakt73hnBJGng4OCqCpFaQBULa4HU5FCz8aNxE-0z87_w?e=tvB5ep&download=1"
# Out:
# --2024-12-16 18:51:30--  https://unimore365-my.sharepoint.com/:u:/g/personal/vpipoli_unimore_it/EZakt73hnBJGng4OCqCpFaQBULa4HU5FCz8aNxE-0z87_w?e=tvB5ep&download=1
# Resolving unimore365-my.sharepoint.com (unimore365-my.sharepoint.com)... 13.107.136.10, 13.107.138.10, 2620:1ec:8fa::10, ...
# Connecting to unimore365-my.sharepoint.com (unimore365-my.sharepoint.com)|13.107.136.10|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /personal/vpipoli_unimore_it/Documents/LAB_WSI_Genomics/LAB_WSI_Genomics.zip?ga=1 [following]
# --2024-12-16 18:51:31--  https://unimore365-my.sharepoint.com/personal/vpipoli_unimore_it/Documents/LAB_WSI_Genomics/LAB_WSI_Genomics.zip?ga=1
# Reusing existing connection to unimore365-my.sharepoint.com:443.
# HTTP request sent, awaiting response... 200 OK
# Length: 7333342054 (6.8G) [application/x-zip-compressed]
# Saving to: 'LAB_WSI_Genomics.zip'
#
# LAB_WSI_Genomics.zi 100%[===================>]   6.83G  60.6MB/s    in 2m 40s
#
# 2024-12-16 18:54:12 (43.6 MB/s) - 'LAB_WSI_Genomics.zip' saved [7333342054/7333342054]

# %% [markdown]
# ### unzip files...

# %%
# !unzip LAB_WSI_Genomics
# Out:
# Archive:  LAB_WSI_Genomics.zip
#    creating: LAB_WSI_Genomics/
#    creating: LAB_WSI_Genomics/TCGA_BRCA/
#    creating: LAB_WSI_Genomics/TCGA_BRCA/Data/
#    creating: LAB_WSI_Genomics/TCGA_BRCA/Data/genomic/
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/genomic/fpkm_unstranded.csv
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/genomic/fpkm_uq_unstranded.csv
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/genomic/tpm_unstranded.csv
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/genomic/unstranded.csv
#    creating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/
#    creating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/
#    creating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-B6-A0RO-01Z-00-DX1.3ADBFF05-92CE-41B5-BD49-CB3CE5B74CC9.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E9-A3HO-01A-01-TSA.0158BAA4-4E64-4235-95B0-28EF4F494A06.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A8-A07L-01A-01-BS1.d3dbb2ea-0d8a-4fe3-8a68-77c86ce5dd6b.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-D8-A142-01A-01-BS1.82a62b94-698c-4047-a13d-083bf49170ed.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A0T4-01A-03-TSC.60866100-7f22-4c86-a99e-5e52ca53c313.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A14W-01A-01-TSA.292e68b2-d49a-46e0-aca5-a587709df55a.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AO-A12D-01A-01-TSA.f28ffd60-5d5f-4fec-8776-bf587f1f2496.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-D8-A1JB-01Z-00-DX1.6CF48257-066C-4B8C-91AA-30A6B4AD4307.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A1FN-01Z-00-DX1.CEE3C59B-6CF0-4D41-8334-6067BB5A8BF7.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AR-A24Z-01A-01-TSA.c9c1b686-7092-4b76-9ce1-7c0fd0b2821f.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A0EP-01A-05-TSE.9746AB87-60C5-41FD-BB30-055B8085B344.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-C8-A26Y-01Z-00-DX1.166EE604-4EF3-401D-99E9-3A9711316CC4.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A18F-01Z-00-DX1.81A81589-2D77-4CD6-BD34-76E292AA031D.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AN-A0XL-01A-01-BS1.c465e036-af63-4ffe-b0d7-fcd07a6251be.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-OL-A66J-01Z-00-DX1.661F7F70-E4D4-4875-B8C4-556F7927F3BA.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AO-A0J9-01A-01-TSA.526836e1-20e5-42a2-89b4-014a69e4838d.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0E6-01A-01-TSA.54e2d7c5-0b53-4221-a8fe-af32465030ec.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AR-A0TV-01A-02-BSB.e4adf5bf-398f-402f-997e-7b5ef9facbe8.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A107-01Z-00-DX1.3BFCCC24-7286-488D-A9E9-98E498AD0767.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A8-A094-01A-01-BS1.f21f55c9-cd4c-4677-ba95-bfe2e6a5ee0d.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A4S2-01A-01-TSA.2C323592-205E-4066-AC07-3CF055B9089C.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-C8-A134-01Z-00-DX1.78D10BCC-98B3-4587-897D-3E27DA28D2EB.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-EW-A424-01A-01-TSA.0D664105-6E7A-4799-8E76-27D720666494.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A8-A08R-01A-01-MS1.cb32d356-ca60-4eab-b186-b63ed3b941d1.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AO-A03P-01A-01-BS1.b5b1b2eb-6a49-4d06-a855-7263aaa78ac1.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E9-A228-01Z-00-DX1.adbeed20-3b14-44fe-a98a-3bf7cecea30a.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AR-A24V-01A-02-TSB.7b8bf9db-edd3-490a-a14b-365e749e3b57.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AR-A5QQ-01Z-00-DX1.4185D6D2-498E-4E71-8CB3-EDB4739C6229.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-C8-A275-01A-02-TSB.b15cf752-5b2f-4f2a-9a03-7519bea81732.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-C8-A12T-01A-01-BSA.bad01673-9581-4bac-b060-56e5bbc2fcd3.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A7-A56D-01A-01-TS1.AD278013-D26A-4CA2-9B22-308E79763904.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AC-A2BM-01Z-00-DX1.162A9FA9-6E61-48BF-B0A5-C6C7640ABD9B.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A15P-01A-01-TSA.e7932941-750c-4fcc-8520-0d7773912874.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A0CV-01A-03-BSC.14215df5-081f-4f57-a912-da96e1f7aa24.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-EW-A2FW-01A-01-TSA.93F3FA5A-4797-489A-B863-4C30CC923B90.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A0CT-01Z-00-DX1.A8564130-49CF-4F5B-B5AB-F4D1A10479FF.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-B6-A0IG-01Z-00-DX1.4238CB6E-0561-49FD-9C49-9B8AEAFC4618.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-C8-A12W-01A-01-BSA.16af5fbe-7bcf-4274-8762-e255595462f6.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AN-A03Y-01A-01-BS1.b7b9c538-7d46-47c8-8071-9b6080f6f330.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-EW-A2FS-01Z-00-DX1.A01C9183-2AC8-456A-B5A6-85C5BB0361D8.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AR-A0TS-01Z-00-DX1.2DB81A2E-16C1-4EE0-8175-65FA46768277.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0BV-01A-01-BSA.1d27d74a-405e-4a7f-befa-6d5f7b1fa8e9.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A1B5-01A-02-TSB.a87d1830-610f-4571-9604-cb92a60e33fb.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AC-A5EH-01A-01-TS1.FE5A32A0-934D-4CD8-9925-78FE99FF13AB.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0BZ-01Z-00-DX1.45EB3E93-A871-49C6-9EAE-90D98AE01913.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0EA-01Z-00-DX1.85FF2B48-2AF7-4C15-A7E6-FCA68CAB76C7.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-B6-A0WW-01A-01-BS1.5df4515e-cc30-4b30-abed-5055a8e40aa6.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A25D-01Z-00-DX1.41DADDB8-3E3F-4F8F-8BE7-C43F8FBCFD2B.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A3KC-01A-01-TSA.7390B45C-AB94-4000-B177-A39D64BC275C.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A7-A4SE-01Z-00-DX1.16BC8401-E40E-4A1A-9BD9-12735C9AE3F6.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AR-A252-01Z-00-DX1.2E7EE069-A0B8-489B-A2F0-3175FB58F468.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A8-A09X-01A-01-BS1.6f6ae7cd-631e-4030-9183-725f5a48c942.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-S3-AA11-01Z-00-DX1.36B83B37-2928-4DB7-A04A-8D511F1183FD.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-OL-A66I-01A-02-TS2.E1A6C9D3-79DB-4585-9879-1AB340415E37.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-C8-A12V-01A-01-TSA.e3f84baa-0829-4683-a26c-b50c7f732f4a.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0BM-11A-01-TSA.e9248134-2bbf-47ba-9b85-4f89f78dd58a.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A14T-01Z-00-DX1.61B4C988-6D75-447B-A5F4-9DE92CEACC9F.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-OL-A5RZ-01A-01-TSA.58A5566D-6342-4BCB-B22E-426DA68338A7.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0DX-01A-01-TSA.326ef6ce-5ee6-4b23-ab87-199c55107405.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AO-A0JM-01Z-00-DX1.94E75EFD-E5F5-4DF8-93A0-ED94CB4D203A.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0AZ-01A-02-TSB.a9b7b640-d2bb-4e2a-820a-d621212eea2e.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0BO-11A-01-BSA.3badb7dc-7b52-4de8-8e6d-db1d35a3806a.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A0YF-01A-02-MSB.2e4e34a9-4701-4b96-b3d6-22d46c792fa9.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A1G4-01A-01-TSA.5d86407e-c67e-421b-8d36-330113e2205a.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A0SU-01A-01-TSA.1501d762-6b57-43d8-b8bb-fe7970b750dd.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A7-A6VX-01Z-00-DX1.F74DA243-C65A-4997-BCA0-F1C89675978C.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-B6-A0IP-01A-01-TSA.83ca6468-2488-4506-baf7-a53290924fab.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-EW-A1P7-01Z-00-DX1.97575C9F-C318-45A5-A4B7-1A902B93FA3F.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A2P6-01Z-00-DX1.9D8060AA-881F-49FF-AEF5-B40A3625A44A.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-D8-A1X7-01A-01-TS1.79381377-01d0-4296-abec-b522c078559c.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A15M-11A-02-TSB.4647c282-a521-407a-b38e-68d193851084.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A1-A0SI-01Z-00-DX1.AB717348-F964-4F29-BBE2-972B7C640432.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A8-A07I-01A-01-TSA.582a3393-09bb-43b2-907c-ba9c27db5b13.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A10B-01A-01-TS1.3bfc66da-c6c4-4246-8794-4b477deba098.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A9RU-01Z-00-DX1.A06BE284-B9DC-4B45-A202-A9D027AEEDD9.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A572-01A-01-TSA.58C737CB-AF59-4664-9E55-2097E80A35FA.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AO-A0JA-01A-01-BSA.c9bb5119-6e0c-4d16-9da4-82a7e553b309.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A18T-11A-02-TSB.330b2105-ded8-4a08-a4ae-de6349c36aa2.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E9-A227-01A-01-TSA.2785cdb8-95a8-4bf8-b479-13b5436983ed.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0B3-01A-01-TSA.b7b39efc-b0b0-402a-bea3-95edd29c5adf.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A7-A0CE-11A-01-BS1.44105666-1880-4b3a-9206-88bf6d300346.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-D8-A4Z1-01A-02-TS2.8713DF53-D04B-41D2-B9BB-3B1D31B1738E.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A0T5-01A-02-BSB.2bc13b46-4db4-4404-aaa0-8625e1ae7440.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A1FM-01A-01-TSA.1154cfd6-e765-4638-ab9c-18dbc9f49148.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AC-A2FE-01Z-00-DX1.C036AE58-3C0D-4DBF-B658-296D03FD6701.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A0ET-01A-03-BSC.a5ea8948-821d-471d-ba1c-3c36807ff5df.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-OL-A5RY-01A-02-TSB.ECCBB7B0-DFC6-4068-9D45-07B1E0C9EF16.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-GM-A2DL-01A-01-TSA.B952C740-284C-458B-A72A-34DDC22B623E.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AC-A3BB-01Z-00-DX1.CE889249-2A5E-44DA-B04E-746BE82CD805.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-D8-A1JU-01Z-00-DX1.355D93B4-E69E-417C-B3D1-3E1AAF1E02FE.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0B7-01A-01-TSA.c22d40fb-49bd-406f-bb75-83d655889804.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-C8-A12Z-01Z-00-DX1.22616420-7C80-42DE-9C44-0F00327681C6.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AO-A0JF-01A-01-TSA.8a6d6272-723a-44f5-9682-6aed7f0964f6.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AO-A129-01Z-00-DX1.BF485416-BF57-4F39-866B-4B1E201876FA.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AN-A0FW-01A-01-TSA.6cba8af3-6ac7-48b5-97f1-37dfb7deefc5.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-GI-A2C9-01Z-00-DX1.90181423-51ED-41FE-9B8F-973A67793D4F.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0E7-01Z-00-DX1.7FEE54C4-3795-403C-85B9-FF932BE56788.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A0YM-01A-01-TSA.af2a6b3d-dbf4-4323-aebe-d8b95053fff3.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A15J-01A-01-TS1.31bb6cae-5ebb-4a35-b6e8-9467f34bc4a8.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AN-A0XN-01A-02-BSB.2ffff1fb-5f41-4d87-854b-ff38bfd677a0.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-D8-A1XF-01Z-00-DX2.1460E522-5B87-4690-8B6B-3183C5D282D6.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A4RW-01Z-00-DX1.4AF8656E-2478-4895-8C59-B0C969F3E474.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A14S-01Z-00-DX1.5C332E99-7296-473A-9917-7EFC38A8251D.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A7-A426-01Z-00-DX1.3058E873-9442-4872-80DA-E8A5B35054D2.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A8-A08F-01A-01-BS1.efa980a8-9019-4413-94a1-72f68fe860e9.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A1B6-01Z-00-DX1.8CD458BE-C4F9-4AF3-A927-18C042E9B4B7.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-OL-A5RX-01A-01-TSA.A2D25C2C-D7C5-4D31-8663-3345DB03780A.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0GY-01A-01-TSA.d5301721-b7af-4291-96dd-220436458f10.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-C8-A1HG-01A-01-TSA.6acb2e7b-9d83-424a-ba81-73c02863eaa4.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-B6-A0X5-01Z-00-DX1.02A9FF1E-EA20-4F2D-A2BB-427A287DE3FD.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-GM-A2DD-01A-01-TSA.A6FD944E-FDD8-4D2F-8304-FFD1617F4C8D.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-D8-A1XW-01Z-00-DX1.10187A1F-086B-4CD9-AC01-ADA2E435CD34.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AR-A1AV-01A-02-TSB.8aac8e77-5af5-4958-86e8-5883c88630fb.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-C8-A273-01A-01-TSA.0eb8a7f8-c3c4-4843-a395-9fffd8b1cc4a.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A7-A26H-01A-01-TSA.347c13da-e59c-4083-a1d1-1117d056129a.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A0D0-01Z-00-DX1.4FF6B8E5-703B-400F-920A-104F56E0F874.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-C8-A131-01A-01-BSA.df5faaa8-e4ac-4a4b-8ef2-ff2063c9ae2f.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-B6-A0IO-01A-01-TSA.c6600460-c39d-405c-80e9-1770d89e2716.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-5T-A9QA-01A-01-TSA.2224E235-416C-4426-BAE4-55961186FB4E.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0AY-01A-02-BSB.581eb097-e917-4666-9344-f62b088cb024.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A1IO-01A-01-TSA.6a2315ed-3e00-4784-8b0f-aa93e6d770d0.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AR-A0U4-01Z-00-DX1.DE722DC5-859D-4866-ADCC-ED98EDBFB588.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AR-A0TQ-01A-01-BSA.ed7f9356-b8cc-4e4b-8caa-d977e4441831.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A0ST-01A-01-BSA.187f1dfd-47df-4e31-883c-62534d8e0dd5.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AR-A1AO-01Z-00-DX1.244DEE5B-0896-452F-A14D-E290260A9D8F.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A04W-01Z-00-DX1.F7E7B945-2ADC-4741-8FCE-ACEA657DB9C7.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E9-A22H-01A-01-TSA.7fc6358e-8ffd-4967-bb2b-b5fa45a9c66e.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-B6-A0X4-01A-01-TS1.5a7fe82b-410b-42da-b90c-a63bc1cb2a38.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-C8-A8HQ-01Z-00-DX1.A08190B5-F17E-4057-9DBD-B2F34CAEAFDC.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AR-A24L-01A-01-TSA.639a9b22-0535-4832-b415-e3af5aee17fb.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A1EN-01Z-00-DX1.F535657F-E2FA-4283-87AE-7DAB663B196B.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A7-A13F-01A-01-TS1.6e5cfefb-e31f-447e-b8cf-d3d5294d3421.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E9-A1R2-01Z-00-DX1.5529C856-4F4F-4F17-94A2-5CEF94A940EB.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AC-A6IV-01A-01-TS1.7FBB836B-E6D5-4883-B323-0D6DE3AD8FF5.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-B6-A0I2-01A-01-TSA.0570e14a-af12-4d0c-94d0-29f5788baa64.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AR-A2LM-01A-01-TSA.F74C259B-C369-43F7-8D4C-9C0F71DCB07E.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-C8-A132-01A-03-TSC.439f1ea4-e2c2-40b7-ad17-0845119b7e8a.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-B6-A0X0-01A-02-BSB.2b68483f-0cb5-4452-a078-c2d7da368efb.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A0D3-01A-01-BSA.a92d21bb-df83-4a6d-87d4-4558f0b8172f.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AC-A2QH-01A-01-TSA.272367FE-1BB8-43F8-9304-219AAFF37D36.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E9-A1N8-01Z-00-DX1.1243AB1C-75A3-4A5E-9674-53992E6DD377.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AR-A2LL-01A-01-TSA.DB96FA2A-150F-4387-9F4A-A3B3861E4746.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-GM-A3XN-01A-01-TS1.C388AECE-6C86-45CF-B9D3-12FC451B8A4D.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A1IE-01A-01-TSA.fe9a2e4e-1c11-45f6-89e8-ee618922dfe9.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0W5-01A-01-BSA.f3d54f51-a213-4c52-8eeb-1220f24364e4.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E9-A1N3-01A-01-TSA.16d2d1ec-d6ab-4fec-98ca-42e0ee333be4.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A1F5-01Z-00-DX1.9A1AA3BB-80B1-473D-B075-8D65A94C4E0B.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A0CR-01Z-00-DX1.F7D36CA5-A4C6-443A-AEED-5B23CD924FA3.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-C8-A1HK-01Z-00-DX1.A15F452B-1260-4106-86D1-05F00082F0CE.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A8-A086-01A-01-BSA.f75d10e3-5a89-4b4f-9b40-6bca77731bb2.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A14V-01Z-00-DX1.D6274B5E-644C-478C-817F-B8BB9262D6F4.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AO-A12E-01A-01-TSA.5c7b82d0-dca5-4778-bc30-1201e08dd832.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A0T6-01Z-00-DX1.207A3883-5B41-40EB-95A1-D64C9610650B.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A8-A08P-01A-01-BS1.c33472d7-2ca3-4195-a4fb-48118362da45.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A15L-01Z-00-DX1.626032DC-D396-48E7-B888-DFEBCF7102FF.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AR-A24P-01Z-00-DX1.08BE8830-C55E-4E2B-9378-371A670C75FD.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AQ-A54O-01A-01-TSA.8BB3A7DA-F7DA-430C-934A-A2302F127862.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AC-A2FK-01A-01-TS1.807C5D36-7171-495C-B6AB-8951B77EAD21.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A1L7-01Z-00-DX1.BE796CD2-2E81-44E8-8CA2-85B4D2A31B64.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E9-A1RC-01Z-00-DX1.8e1008da-b17b-4096-a070-f536fe8ce52d.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E9-A248-01Z-00-DX1.C991932F-39D4-4F2C-91C3-CE12B5BAEDB1.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E9-A22E-01Z-00-DX1.3d5b1ba6-466f-4852-b1fc-bc29ef3be9a2.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AN-A0XS-01A-02-BSB.cff535fb-0ae9-402b-97ab-5c6cd09a9959.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-GM-A2DM-01Z-00-DX1.652038F4-C370-40EB-A545-51062783C74C.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-LL-A740-01Z-00-DX1.757D94A5-EF0F-4A0E-99A9-8809B66438DA.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AO-A0JJ-01Z-00-DX1.D5B636F5-1B47-4033-9938-9DC8CD48CEE9.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AN-A0XT-01A-01-BSA.25304183-65ab-4653-88f2-02589fcae9e2.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0H0-01Z-00-DX1.B3B394DD-1F4E-42CA-BB51-C002E423B3D0.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E9-A1N6-01A-01-TSA.cb99a09f-ab42-403f-a8b1-f45be63f2946.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A1EW-01Z-00-DX1.A6A5F9C5-FB97-4DA3-A1EA-1F84BC006681.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A0T3-01A-02-BSB.19f759a7-4b0f-43f3-b1ac-bce827f93fc6.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A1FH-01Z-00-DX1.F90A691F-B6DB-4C4A-9975-9A2CB01F29E2.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0B6-01A-01-BSA.F0754BB4-6170-42CB-931F-04A324BADD47.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AN-A0FF-01Z-00-DX1.A23982C3-E0EB-4DB2-84EE-26E0005E3F66.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A0YT-01Z-00-DX1.63CA3E36-B3E4-4D3F-9F80-2703970DBE5B.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A04N-01Z-00-DX1.9E9B7DB0-1CF1-4631-8292-A9DBCA0BD37C.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-B6-A0WZ-01A-01-TS1.d42e7513-9258-49ac-82c3-0e1be2af24cc.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A7-A13D-01A-01-TS1.e486c65b-370b-41df-8cd9-bcadaf1f88bd.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AO-A03N-01B-01-BSA.e6642355-b3e1-4cc4-81ca-129b9ddf9240.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A1G0-01A-01-TSA.191b630e-777f-41f9-9510-22ed5faa316a.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E9-A3Q9-01Z-00-DX1.2D0CA5D4-CCE5-4647-BFB3-D5359F53DA83.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AC-A7VC-01A-01-TS1.BB26DD06-AFA5-4F5D-A6F6-99A3D154C878.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-UL-AAZ6-01A-01-TSA.9B3C23C9-6286-48A3-B084-78E7A7CCE9E1.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AR-A2LK-01A-01-TSA.53C36847-0443-432D-97FF-02949CCBA21B.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0C7-01B-01-BSA.eff3406d-2af0-435f-8aa9-fd77dbba35dd.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A1LG-11A-04-TSD.4092d9f5-3951-4590-9def-81ba1380239f.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AN-A0XO-01Z-00-DX1.204E554E-B1A8-41AD-8E39-62484DF4E3CD.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AC-A8OQ-01A-01-TS1.8574E320-4426-48B9-88D7-60AD5EA0A921.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A3XX-01A-02-TSB.01B489E3-2FE7-4ED4-AF28-04850E1FD9FF.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-C8-A1HI-01Z-00-DX1.C6D0F8B8-55ED-477F-BAF7-AA05D0449CC8.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AR-A24R-01Z-00-DX1.47D79205-63E7-43E6-A513-2CD10DFA53C9.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0HF-01A-01-BSA.e917388d-c4db-4345-b7de-172bc1894173.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E9-A247-01Z-00-DX1.3B2DF1CB-054A-44C4-9AD5-D8FA6D386A93.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A1F6-01Z-00-DX1.E83F0DC0-EA2C-4641-81B0-8702B9C5D579.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AC-A2QI-01A-01-TSA.4BA73556-9C89-4F0F-AAD5-A5F7CADA4593.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A8-A07G-01Z-00-DX1.37E8A762-8141-4BE6-935A-B3DCB712BB4A.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A15D-01A-01-TS1.3079ed1e-0fe7-45b1-9ec1-c19c5d0b4df8.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A1AZ-01Z-00-DX1.FE769F5F-385B-4DCF-819A-735C98D84FA8.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A8-A06Z-01A-01-BS1.d29f4573-c196-4e24-813d-131a00f55b78.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-GM-A2DI-01A-03-TSC.DB9E24D8-2B07-483E-A490-2B64240EFCEE.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-EW-A1IW-01Z-00-DX1.0DE87057-951F-4887-A2D5-485736D66E4E.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-B6-A0IC-01A-01-TSA.2fd2c097-b937-4649-abf3-f01a077e5c06.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-B6-A0X7-01Z-00-DX1.A2AA8FE9-CF43-434A-AE72-7277D124BD0A.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-OL-A66H-01A-01-TS1.192101A6-CFBF-432F-935B-049CE2816476.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AN-A0FT-01Z-00-DX1.6F263AB3-FB1D-4056-AEC2-4F163017324F.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-W8-A86G-01Z-00-DX2.DEC2CC1C-3662-43C6-A5CB-EC94B343FA3D.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AO-A124-01A-01-BSA.0770840e-d781-45f2-bbc8-034f0e4138a5.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A42U-01A-01-TSA.E8076E2D-A5D6-4AD1-8ABC-2EE650A0563A.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AR-A0U3-01A-01-MS1.64c1dbeb-4a3b-4062-bdf4-2ada1e7c64c4.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A0YG-01A-02-TSB.8bd4f37a-7944-4379-910c-621a80229783.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E9-A1RE-01A-01-TSA.a7672cd5-758c-4580-9390-26607eb98d7b.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AO-A0J4-01Z-00-DX1.2EFC978E-8DF5-4254-9598-C0910B17C5C8.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-C8-A27B-01Z-00-DX1.5A8A14E8-6430-4147-9C71-805024E098CB.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A15A-06A-01-TS1.bc17c613-409e-4308-beae-d7dea1493c10.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A7-A0CJ-01A-02-TSB.e090ba35-b5b7-469f-a267-8c8c68bc2c2b.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-B6-A0RL-01A-01-BSA.448744f8-8c40-4d41-ad86-e59e8fd63b47.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-OL-A5RW-01A-01-TS1.4A172D57-5F02-4680-8106-81459FC20B26.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A0YC-01A-01-TSA.dfb0f795-b54a-44fd-8ddd-105ac7c51d35.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-B6-A1KF-01Z-00-DX1.2E08E830-4216-4CD0-9646-1F489300E11D.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-D8-A1XT-01Z-00-DX1.9E4DEEEB-AB0A-45F6-A69B-65B3E6F22D46.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-5L-AAT0-01A-01-TS1.E7894281-DAB5-4603-B42A-A4C71FBE3D37.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-B6-A0IH-01A-01-BSA.4bfc7c55-1aaa-431a-a252-9426bb2b469b.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E9-A1NC-01A-02-TSB.45067FA5-9305-45D9-A343-FCCECF9BABF4.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-D8-A1XB-01A-01-TS1.ef5ac532-0ea5-49cb-b959-4f7463fd9d97.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-S3-AA12-01Z-00-DX2.4F0A4F18-41C7-4497-A7B8-5DCE610E08AD.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-C8-A133-01A-03-TSC.ec2ffe8b-a27e-4f73-bff5-af3cb1020b32.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0BF-01Z-00-DX1.934DF984-9054-4B20-B85B-9CF94B8DC3D4.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A7-A4SD-11A-04-TS4.765F46C1-EDCF-4CD8-AE39-F82685BA2C98.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-GM-A2D9-01Z-00-DX1.AF4BF2DD-05FB-400B-A1BC-6E7C9B9DDF05.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-PL-A8LX-01A-01-DX1.9646D69F-A764-4246-9243-67A63006DE96.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E9-A1NH-01Z-00-DX1.20FF11B7-DAF0-41C2-B7C5-449BA5268EC0.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A109-01A-01-TSA.21eaebd6-c736-452d-96ea-60ecdbd07764.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A15C-01Z-00-DX1.26E13415-1D37-43C7-9EBB-4411BE7FCE10.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0C0-01A-02-TSB.b5d6fdae-cc88-4ded-a599-f778187bdc37.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A0EU-01Z-00-DX1.13335BEB-63D4-469B-A389-8A079A096129.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0DI-01A-02-TSB.c1a37b06-e872-44b7-9dd2-2b3e2b363076.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A1G6-01A-01-TSA.da860c75-25a5-4542-b546-e14c8beb8649.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A4S3-01A-02-TSB.8DF9D6C3-017C-448F-A04B-68F2F69279B7.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AR-A0TZ-01A-01-TSA.e8ec1762-8ae8-46ca-bece-0f89cb7bd3c5.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A15K-01Z-00-DX1.9F424BE2-9BFE-4DFF-8CC9-10D2DADBBEA7.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A1EU-01A-01-TSA.ce198ff0-3faf-4c61-b810-eac6d14f9a28.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A570-01A-01-TSA.3BF71DC2-AF5C-400D-BF49-A6A7483481BB.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AN-A0XP-01Z-00-DX1.A4EE3970-5C1F-482E-9AED-F1E3C52A776F.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-D8-A147-01A-01-TSA.8c6e7351-307e-4196-9f62-b733c7206e14.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-MS-A51U-01Z-00-DX1.490DE85A-ECE5-4E2A-9657-841BE6FFCCA0.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AO-A1KT-01A-01-TSA.896a18ea-090c-4adc-aa95-7614c17ff75d.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A8-A09C-01A-01-BS1.22b0b4ca-9aa2-4ef8-a0b3-933476fbd987.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-3C-AALJ-01A-03-TSC.272FA991-8382-409A-A00A-9A3BAA6EE041.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0BR-01A-02-BSB.63ea0e68-49cf-4897-834b-d11519db02ec.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E9-A1RA-01A-01-TSA.b2e935c7-c2cc-4ef8-9f40-4a80a625cc89.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AO-A0J3-01A-01-TSA.86832b75-652d-40a9-a29a-1638bcce1aef.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E9-A226-01Z-00-DX1.14f1f4c7-4e6e-4574-af20-60d2ab511b2a.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AC-A3HN-01A-01-TSA.D9B963D0-367F-4D94-B4CC-9C02FF529CB2.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0H3-01Z-00-DX1.C6D4DFB9-A4FA-40B2-90EF-75294CBC4523.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-JL-A3YX-01A-01-TS1.B78AA02B-6BBE-4E77-A30C-9D98F2AA11B9.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A18N-11A-01-TSA.67433f2f-b31c-420a-adb5-358ca3dfeb3e.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E9-A1RG-01Z-00-DX1.044C235A-75AE-4C7D-AC7F-56C8E64354AA.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-GM-A2DK-01Z-00-DX1.4F81A585-9549-454C-8E15-2E4545795460.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0H7-01Z-00-DX1.21502FEA-DB37-4630-BA42-778DDF3A6D17.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A1-A0SD-01A-01-BS1.24ae9ce9-ef51-4cef-a095-1681d4bdd2fb.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A8-A08B-01A-01-BS1.cd256d6e-99c5-4b32-8bbc-7c1811004b8b.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A18J-11A-02-TSB.82433f37-c0c6-4430-88e0-b05267aa4845.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-D8-A73W-01A-02-TS2.A9875DA2-4BD8-4A07-BFDE-D71336E02072.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-LL-A6FP-01A-01-TS1.E618EA84-C425-4B27-BCCA-E1BE93873F0D.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AO-A1KO-01Z-00-DX1.EEB5E0A0-92B2-42CD-9F7A-00E9250B561F.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AR-A24Q-01A-01-TSA.cca6142d-12a1-410b-b480-7de4d6f3270f.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A1FV-01A-01-TSA.1ef7e33c-4e9f-46fb-8600-e2028e666b58.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AO-A0JB-01Z-00-DX1.250FE098-345B-4981-9236-0519E1C9058E.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A8-A090-01A-01-TS1.6fd65ca8-2e04-4f0b-902a-070cd65c2d93.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A3XV-01A-02-TSB.FF8434E6-B703-43FE-AC0A-AE53131F1EC6.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A3DX-01A-02-TSB.4BD3DC88-03E9-426A-A7D4-033DD742279C.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0H9-01Z-00-DX1.8AE869C6-5C78-4D52-AC8B-5B6FD5FD91AA.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A42V-01Z-00-DX1.B6D78256-05D1-45FA-826A-1B8554D60B7D.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-B6-A0I9-01Z-00-DX1.78E1D43A-507E-482E-B988-AF13B12B4497.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-OL-A5RU-01A-01-TSA.EADD3E6A-8614-4BE9-B061-66E57EDD1781.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AN-A0AK-01Z-00-DX1.4B410152-8588-4000-870A-B31B21161015.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-B6-A0RG-01A-01-BS1.152d245b-c2d3-4d0e-803d-f0eb76273116.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-PL-A8LZ-01A-02-DX2.E2697718-12E1-4D7C-9ED8-0A71C6D855B8.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E9-A5UO-01A-01-TSA.8DD0A003-C13A-41FD-B59B-16DD205C5003.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A28Q-01Z-00-DX1.C6D1CA93-6B2A-4722-9270-5D56592D833D.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-D8-A13Y-01A-01-TSA.3b97c805-0681-4e8d-9dd9-f24a9c2bb4cd.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-D8-A27W-01Z-00-DX1.CE2D4FEA-284C-44AF-A70F-7956D91CCB29.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0E1-01A-01-BSA.57534115-65b7-48cc-b124-13b8f3c15d48.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-S3-A6ZH-01Z-00-DX1.E728FF79-4921-436F-BFF5-5B782C0EEB9A.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A8-A0A7-01A-01-TS1.dfc11237-aff0-442f-8a39-ce81f0d4aeb1.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-WT-AB41-01Z-00-DX1.75BDFDF2-CD87-46D1-B32C-725741CB02BE.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-B6-A0IM-01A-01-BSA.e4fce1ac-0800-4e45-a3bc-f9bcb2ea825f.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A7-A26I-01Z-00-DX1.0077D012-BC14-4E96-84F7-A1A6A3A778DF.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-B6-A1KI-01Z-00-DX1.EFAA08A8-02EC-4A9B-AC6B-79BF2DC5A2AA.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AR-A2LR-01A-01-TSA.E8716040-4787-4C4B-903F-B26AB7FBDD6E.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-B6-A0WV-01A-01-BS1.50bdea76-5591-45f4-8743-d420e5c0063e.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AO-A1KP-01A-01-TSA.944cf99a-9e79-482d-b09c-3a140806e56f.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AN-A0G0-01A-01-TS1.35437324-f765-4522-aea3-c564491b948f.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-C8-A137-01Z-00-DX1.87F3775D-A401-4D5E-843F-8FB1D4BE97F8.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AC-A2FB-01Z-00-DX1.A4D93E32-BBD7-45E4-8ACF-3724B059ECBC.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AC-A7VB-01A-01-TS1.E9E70973-2C6B-4EF4-92C2-39B6E9FAE0AF.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A1BC-11A-02-TSB.f715b4ad-feea-405f-be58-3d2f70e5989c.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-3C-AALI-01Z-00-DX1.F6E9A5DF-D8FB-45CF-B4BD-C6B76294C291.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AO-A126-01A-01-BSA.d9c05421-91fc-4fdd-988d-2b404fa24095.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-OL-A66L-01Z-00-DX1.E01BA275-57A5-49DF-9376-1AD0BDFFF7E2.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-D8-A1JT-01Z-00-DX2.8DB9BB5B-17F3-4D80-835D-872BA275FD3B.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A574-01Z-00-DX1.60341091-B118-4F20-9ADB-FB2886790B0E.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0BD-01Z-00-DX1.CD4A6FC2-BA8C-4E30-972A-E6CD1BEAD8AD.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AR-A0TY-01Z-00-DX1.089EB6B4-9921-441D-84F3-C64C97AFC3B4.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A10F-01Z-00-DX1.18F9324C-A38F-478E-95DF-B8E172D0DD07.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AR-A1AP-01A-01-TSA.462d1ac8-1c00-4690-9d0e-975853c4c5f2.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-OL-A66K-01A-01-TS1.B088994F-5660-4401-B5AD-A6C8493172BC.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A108-01Z-00-DX1.B110ED43-08A4-476A-A658-1CA75F7C0DDE.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-LL-A442-01Z-00-DX1.9275EDBD-1C89-4AF3-B02B-19F613A4E083.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AC-A3TN-01Z-00-DX1.F00E81C7-0CA2-49E8-A30F-DE423538E93C.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AR-A24T-01A-01-TS1.3af5a9b7-b62c-4cf9-aa78-5671b180e901.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A1B4-01A-01-TSA.4a536aa0-47af-4c66-a151-a5d5db65a566.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E9-A1NG-01A-02-TSB.b717018b-f4d3-4b8c-8057-4db7173faa83.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AO-A0JC-01Z-00-DX1.C8DD421B-9799-4FE7-9224-5EAC6ED1028E.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-D8-A27V-01A-01-TS1.4F3FB63F-C45A-4C28-95F3-C2C8682993DA.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-LL-A6FR-01Z-00-DX1.107010FD-8EDD-406D-B4DE-DEC9E85576FF.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AC-A2FO-01Z-00-DX1.46929316-D7ED-4D69-B068-409BFFBCEC4D.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-D8-A27R-01A-01-TS1.b39b1443-6a3f-46c4-b7ec-18dab2223450.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A8-A08X-01A-01-BS1.e4d6c832-f42b-4a1d-8a98-4fbdb3ce0e2a.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-EW-A1OV-01A-01-TSA.9ccd6a13-34e4-4d98-9a18-3e7136ec0a13.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0B8-01A-02-TSB.36cf2fc1-2b18-48e7-9d2d-0892fdf17b93.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A7-A3J1-01Z-00-DX1.92895B92-5F95-4EA3-9237-4CAF63CDE3FF.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A0T1-01A-02-TSB.63e971bf-39ec-41c9-986e-a1937437dea8.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-B6-A0RS-01A-01-TS1.f7a616c8-c091-46b7-8dbe-90b1343fe3b1.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AC-A6IX-01A-01-TSA.3F87BB26-267E-4FC9-81E2-745AB81A2CCD.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-B6-A0RE-01A-01-BS1.b3d8a60d-a66a-4cf3-8616-edc125bf48f1.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0DZ-01A-01-TSA.482fc6f8-5c8b-494e-a821-628daa343534.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AR-A24N-01A-01-TSA.b617b299-5c2d-45c3-b018-6b8cf0e84811.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A7-A4SC-01A-01-TS1.039AAA5C-0866-45EF-9FD2-36F9A6AA58AA.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A14X-01A-01-TSA.8d861810-a681-4877-bccd-aa0f83074a2a.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A1L8-01A-01-TSA.2b88c3e8-d202-4b83-8390-126f33606d7a.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A8-A095-01A-01-BS1.4a8ab901-ac44-4973-8507-03d54f82e067.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-LD-A7W6-01Z-00-DX1.3E125146-B447-4973-AE09-6D374970B46C.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0H6-01A-02-TSB.c3d00ef3-faa9-416f-b8dd-85e30227482d.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A1LA-01Z-00-DX1.AE49E943-B830-4ED9-B09E-E499441BC2EC.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-OL-A66O-01A-01-TS1.33A92C45-789F-493B-8D67-26EFB0169A95.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-LL-A9Q3-01Z-00-DX1.94FA76F5-008A-401B-BFDC-817804BAE5F6.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-D8-A1Y0-01Z-00-DX2.7C25E941-12A6-46CE-B1A5-488D08E35684.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A158-01A-01-TS1.7dc3c147-bcdb-4e14-83ef-71e24102846a.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A10A-01A-02-BSB.79389df7-59f1-427f-80d4-3a959407407e.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A203-01Z-00-DX1.FAE40A13-0C4A-415F-9396-01041FF6B855.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AN-A0FZ-01Z-00-DX1.9555AF11-3A0D-4FE3-AE91-09DA77B175CA.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0EB-01A-01-TSA.12af0d04-ac02-49b1-b2a7-67af4dce098f.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A7-A13E-01A-01-TSA.4f107ed6-13b7-4685-9baf-d7ba5a4adeff.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-EW-A423-01A-01-TS1.268BA465-DA2E-48D1-B9D7-C0C706499D09.pt
# ...
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-LL-A5YP-01A-02-TS2.C03716AC-F6CE-4982-9C7B-75688D7C463D.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A1LL-01Z-00-DX1.D1AA1613-902C-4579-9612-48A76042B0AE.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0W4-01A-01-BSA.010d7af0-073a-48aa-a257-10583b33c6f7.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A0EN-01A-01-TSA.d57caa16-813c-41c9-9b9a-3e906e576bb0.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A0EQ-01A-01-BSA.fa7a323e-2939-4941-a56f-3b7352b16050.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AC-A3EH-01Z-00-DX1.30160436-4DE9-4F99-87E2-214E3CA47289.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AO-A12F-01A-01-TSA.6ed8979a-e4f3-42b1-950f-64908238f50b.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A8-A09Q-01Z-00-DX1.C7240AFB-5971-4577-812C-A255C249001A.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-D8-A1XR-01Z-00-DX2.A103FB8B-4397-4DD4-8587-90A736407484.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AR-A1AS-01Z-00-DX1.72979519-0A90-42AD-9F23-1991F75C8CE7.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E9-A1R4-01A-02-TSB.ba1d4e07-3128-48a3-81c6-b3b3b4b961c3.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-B6-A0RM-01A-01-TSA.12501542-b8cb-4b36-bc66-67ef4578d7d1.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A7-A3RF-01Z-00-DX1.E60647BC-229D-4409-A564-EE0945F912EE.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A28O-01A-01-MS1.B25C7456-CDA1-4989-97F6-13B9AB7D3688.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-D8-A1JN-01A-01-TS1.d8e7d0ee-6285-4633-a790-6a746980ba73.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E9-A54X-01A-01-TSA.6FDFF7F9-3D49-48CF-96FE-ED6E9D6A1014.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A0CW-01A-02-TSB.8bc46f2e-400f-4de8-aa07-9c632cea132f.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AN-A0FJ-01Z-00-DX1.97B60767-916E-4938-9D0B-E6C0FE1CB3FC.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-GM-A2DH-01Z-00-DX1.5790F15F-2A0F-4929-8FE4-18A557007989.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A0EM-01A-01-TSA.c792570c-b567-47a4-8092-4f9021843df7.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A0T7-01A-02-BSB.8f69b301-dcf9-4a7f-a504-187f9a11252a.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E9-A54Y-01A-01-TSA.7EF6FC52-B788-4ACD-B92A-A59BE4F11BDD.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AQ-A04L-01B-02-TSB.fb5e4cf2-39a4-40d1-b7c4-6e2672097bfe.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-B6-A0WT-01Z-00-DX1.7ED21DA2-A3D8-4DCA-9742-963879A658D8.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A8-A07J-01Z-00-DX1.FE16248C-D890-4750-A9FC-5F72BE8D8B85.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AN-A0AL-01A-01-BSA.56e46756-aa0f-4c59-a189-ee4c9601b3ea.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A8-A06U-01A-01-BS1.1182603b-20e7-4a0e-a686-055841cf5ca4.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0W3-01Z-00-DX1.38DCA2B7-1A54-4FFA-BABA-29F80974BB17.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AN-A046-01Z-00-DX1.C529B94F-AFE3-4701-BC98-5D6EDF7B82C0.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-OL-A5S0-01A-01-TSA.3BA4D96B-18A7-4262-8D13-88C8D98B14A6.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A8-A099-01Z-00-DX1.B19C28B5-FEBC-49B4-A60E-E6B85BB00DD7.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A8-A08H-01Z-00-DX1.6AA6A530-3BD3-4582-9D6B-8AE3B4A73948.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A0EV-01Z-00-DX1.EA8C5594-BA4F-47A8-949B-D536E00E62C9.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AN-A0AM-01A-01-TSA.63a22828-01b7-4b90-976d-7c32ccb9889d.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A7-A425-01Z-00-DX1.812A94B1-0403-4298-A6C5-F71AFD3A9995.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AO-A1KS-01A-01-TSA.45cfd1b6-e36a-4262-889a-e8540d9244f0.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-PE-A5DD-01A-01-TSA.B71D5B6B-7526-4C1F-B656-2F5A8B8F3086.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A1BD-01Z-00-DX1.A2AFF7AD-ED47-43E4-87FE-62882BAEB8DA.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-D8-A1XY-01Z-00-DX1.AC051FB4-1D51-449B-BF2D-9DDB4382414C.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AR-A255-01A-01-TSA.85414c8e-dc54-4ae2-80dd-c58db439c5c7.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AO-A03O-01A-01-TS1.dbeaa688-64e0-48ce-bd9a-cfba3407bca6.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A0SW-01Z-00-DX1.E1EA0407-B831-4D75-826E-80B82B821797.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A15G-01A-01-TSA.ddb91e88-5cdd-4f96-868d-7c6e7c533be6.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A7-A0DA-01Z-00-DX2.90C93176-C3C6-41B3-B34B-B16F1A1779E6.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AO-A0J7-01A-01-BSA.24323379-2daa-45cf-b3e8-f8e4da05a90a.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-D8-A1XZ-01Z-00-DX1.8E51A61D-B01C-4A52-8F5D-44D2ABCA46FC.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A0CS-01A-01-TSA.1c053f5f-ca22-41a9-b815-681eb2a4ea5e.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E9-A22B-01A-01-TSA.c56b2348-5c2c-4212-98f9-fbdcc444963b.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-C8-A26V-01Z-00-DX1.6E86DF74-D575-4969-8142-963D9DF5208F.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A0CX-01A-02-TSB.eae9814e-e25c-4dfe-9564-e348c74699ba.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0HN-01A-01-TSA.82c8d845-2b00-401b-af1a-70573b4a95d3.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-B6-A2IU-01A-03-TSC.BB626BA9-ECDE-4EFF-8854-DA1C2A9638EA.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-D8-A1JF-01A-01-TS1.717683b4-e835-445c-9878-9d3f319792ff.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A18R-01Z-00-DX1.07E6FA7F-5072-4327-9982-A40F010B7532.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AC-A2FF-11A-01-TS1.5B36FFA1-3190-441A-869D-9280242BCE21.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A18S-01Z-00-DX1.B36FC684-0010-4ABB-9E25-303C8DF1C4E2.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A14Y-01A-02-TSB.57b8ab8a-d0b6-419a-8363-edbb7aab4bff.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AR-A1AL-01A-02-TSB.a5a169e3-b2b7-4a89-95fb-ee01621d32ee.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-D8-A1JI-01Z-00-DX1.9BDB647F-EEAB-4235-BE44-A3815A48CCE0.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AR-A1AI-01Z-00-DX1.5EF2A589-4284-45CF-BF0C-169E3A85530C.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A8-A08J-01A-01-BS1.c5948da8-a676-4cbf-819c-b636c968cf46.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0EE-01A-01-BSA.3b661349-b956-42ea-8872-db00f9a397f2.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0E9-01Z-00-DX1.5FC4A5E1-3984-4869-9FFB-C0C7F9EAF5FE.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A15I-01A-02-TSB.961e62b4-3906-4076-a261-5b33f151c664.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E9-A2JT-01Z-00-DX1.49C2B936-3B1A-4014-8B43-26D483DEF53A.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A8-A09G-01A-01-BS1.d16e6e1e-268a-4973-97c5-8aa9cdef622b.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A04U-01A-01-TSA.d9c6a9aa-23c9-43d8-a59d-d5d4b474cbb6.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A8-A09V-01Z-00-DX1.2D6731CA-5712-4EB8-8602-E53301BF4238.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AC-A23E-01A-01-TSA.e43478f1-47e9-4b9c-8506-1978e481de57.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AC-A23C-01Z-00-DX1.0E67C785-83D3-49AF-B600-FB5B909AE6ED.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-EW-A1P3-01A-01-TSA.bc5f0d8f-aa52-42b7-abe1-f729c2bc5dff.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A0YH-01Z-00-DX1.FBA5E711-8275-45B3-BC20-5A786EE23548.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A0CK-01Z-00-DX1.C3226BD1-11B0-4034-946A-BAB42958CE85.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E9-A22A-01Z-00-DX1.d986c9eb-2c54-4663-a54b-04c0756db6db.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A8-A091-01Z-00-DX1.1F38CADB-A093-416E-A8A8-31E61CD730BA.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A573-01Z-00-DX1.D6633BC2-524D-4153-952F-6B1D8D067370.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A1-A0SP-01Z-00-DX1.20D689C6-EFA5-4694-BE76-24475A89ACC0.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-EW-A6S9-01A-02-TS2.C421885C-98C3-45B9-B01B-49779B87922C.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-D8-A27E-01A-01-TSA.48a9ccf5-588d-4f44-a026-2ba63d43c5fd.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A8-A097-01Z-00-DX1.4D06990E-E759-40F0-9106-59408CF350E5.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A8-A076-01A-02-TSB.6a8058db-d92b-4a26-8b84-5ccd4cb198e3.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-D8-A1Y1-01Z-00-DX2.B58DC955-F864-4E78-8B1A-8156E2F7D554.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-EW-A1OZ-01Z-00-DX1.9639BB06-FF02-475F-A89D-773BE12721CC.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-D8-A13Z-01Z-00-DX1.517140BB-D34C-42F8-952C-340EF16D382F.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-EW-A1J5-01A-01-TSA.e6a343d8-808e-49ba-8ccd-a9237523f59b.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AR-A0TU-01Z-00-DX1.2CBBDDAB-C1DD-4205-A555-431542F9C069.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AO-A03M-01Z-00-DX1.9998A9A0-D0A6-48FC-80FB-AE597CB9E8AA.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A1B1-01A-02-TSB.8d1372de-544d-4c67-9e8f-09bcd33db672.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A8-A08O-01A-01-BS1.4d78f0ab-bbcc-469e-a381-a4e9b763fd03.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-3C-AALK-01A-01-TSA.B64ED65E-C91A-42C9-89A5-1B099C7112C3.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-D8-A27K-01A-01-TS1.b8d6df65-efe5-4317-b903-b93ec05aaa5f.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A15E-06Z-00-DX1.D394A007-91A2-4445-9B4A-1629EE684A51.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-D8-A1XO-01A-01-TS1.aedcf4d8-d516-478d-a39a-88cf094d580e.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-EW-A1J6-01A-01-TS1.cbeda021-a81c-4a79-a505-f8f0b4cb6620.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A106-01A-01-TS1.c5fe7052-cb83-49bd-8c1d-a82067606921.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A18Q-11A-01-TSA.cf47b7ab-8a52-4867-ba62-0caea0107a9b.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-B6-A0RV-01Z-00-DX1.C46C2937-868D-47B7-B9B9-E51F5433BE97.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-C8-A12X-01A-01-TSA.3436a21f-d32b-4645-b767-c6cd450893f0.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-LL-A5YO-01A-02-TS2.5819C502-EEA4-4D98-B4EC-E184B374ECFB.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A3Y0-01A-01-TSA.E893B34E-47F9-4B40-B0AC-3D217F32F614.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AN-A0AJ-01A-01-BSA.e768585b-8fac-4998-88a6-29983ae06c92.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AC-A3W5-01A-01-TSA.8677B526-3F4D-4B52-A02E-F05244B8479A.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-AO-A1KR-01Z-00-DX1.BFB2E69B-E23C-4542-9CBF-EDD040B985AC.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-B6-A0I1-01A-01-TSA.95CA1DC3-0B4A-48E0-806F-841FEF39F941.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-C8-A1HM-01Z-00-DX1.F93C3F56-3AA6-4D38-B51E-4694CBEA3830.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0HQ-01A-01-TSA.177676f4-76db-4918-a57e-99124cfa3f34.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0DV-01Z-00-DX1.2F0B5FB3-40F0-4D27-BFAC-390FB9A42B39.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-E2-A576-01A-01-TSA.B5BE3814-145D-4236-8152-BA39A1B7D0D7.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-D8-A1XM-01A-02-TS2.3863ab4d-f89c-4a1c-8965-ff12b9c8dc4b.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-A2-A04R-01A-04-TSD.f8e56971-436f-495e-a7c2-3a147059fc62.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-B6-A0I5-01A-01-TSA.0ca5d58c-89b3-4d0e-9b39-8d74245286ff.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-S3-AA17-01A-01-TS1.E8CCA5B9-9FB4-4A1B-AE41-8745D4FAFD8B.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-B6-A0IB-01A-01-BSA.2cd7198d-8930-464c-b313-3182d7910f41.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-OL-A66P-01A-01-TS1.239F863A-670C-45FC-ACD9-B38395FC2383.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-BH-A0DP-11A-01-TSA.77dc8d08-cc2b-4e5f-b739-caa069549979.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files/TCGA-B6-A0RT-01Z-00-DX1.6C2BA663-D61B-404B-B62C-B81747B6A3AC.pt
#   inflating: LAB_WSI_Genomics/TCGA_BRCA/TCGA_BRCA_labels_multimodal.tsv

# %% [markdown]
# ### Multimodal Survival Dataset Class

# %%
TCGA_BRCA_dataset_config = {
    "name": "TCGA_BRCA",
    "parameters": {
      "dataframe_path": "LAB_WSI_Genomics/TCGA_BRCA/TCGA_BRCA_labels_multimodal.tsv",
      "pt_files_path": "LAB_WSI_Genomics/TCGA_BRCA/Data/wsi/features_UNI/pt_files",
      "genomics_path": "LAB_WSI_Genomics/TCGA_BRCA/Data/genomic/tpm_unstranded.csv", # fpkm_uq_unstranded # fpkm_unstranded # tpm_unstranded # unstranded
      "tissue_type_filter": [],
      "label_name": "FUT",
      "censorships_name": "Survival",
      "case_id_name": "case_id",
      "slide_id_name": "slide_id",
    }
}
TCGA_BRCA_dataset_config = Munch.fromDict(TCGA_BRCA_dataset_config)

# %% [markdown]
# ### inspect genomic data

# %%
genomics = pd.read_csv("LAB_WSI_Genomics/TCGA_BRCA/Data/genomic/fpkm_uq_unstranded.csv", sep="\t")
genomics = genomics.set_index("Unnamed: 0").dropna()
genomics

# %% [markdown]
# ### inspect main dataframe

# %%
dataframe = pd.read_csv("LAB_WSI_Genomics/TCGA_BRCA/TCGA_BRCA_labels_multimodal.tsv", sep="\t")
dataframe = dataframe.dropna()
dataframe

# %%
class Multimodal_WSI_Genomic_Dataset(Dataset):
    def __init__(self,  datasets_configs = [TCGA_BRCA_dataset_config],
                        task_type="Survival", # Survival or treatment_response
                        max_patches=4096,
                        n_bins=4,
                        eps=1e-6,
                        sample=True,
                        load_slides_in_RAM=False,
                        ):
        self.task_type = task_type
        self.load_slides_in_RAM = load_slides_in_RAM
        if self.load_slides_in_RAM:
            self.slides_cache = {}

        self.datasets = {}
        for i, dataset_config in enumerate(datasets_configs):
            # config = yaml.load(open(dataset_config, "r"), yaml.FullLoader)
            # config = munchify(config)
            config = dataset_config
            if config.name in self.datasets:
                raise ValueError("Dataset name {} already exists".format(config.name))
            self.datasets[config.name] = config.parameters # asser config.name in datasets

            dataframe = pd.read_csv(config.parameters.dataframe_path, sep="\t",dtype={'case_id': str})
            dataframe = dataframe.dropna()
            dataframe["dataset_name"] = [config.name for _ in range(len(dataframe))]
            if task_type == "Survival":
                rename_dict = { self.datasets[config.name].label_name: "time",
                                self.datasets[config.name].censorships_name: "censorship",
                                self.datasets[config.name].case_id_name: "case_id",
                                self.datasets[config.name].slide_id_name: "slide_id"}
                dataframe.rename(columns=rename_dict, inplace=True)
                dataframe["time"] = dataframe["time"].astype(int)
                self.case_id_name = "case_id"
                self.slide_id_name = "slide_id"
            else:
                self.case_id_name = self.datasets[config.name].case_id_name
                self.slide_id_name = self.datasets[config.name].slide_id_name
            # dataframe = self.filter_by_tissue_type(config.name, dataframe, config.parameters.tissue_type_filter)

            # load genomics data
            genomics = pd.read_csv(config.parameters.genomics_path, sep="\t", dtype={'Unnamed: 0': str})
            genomics = genomics.set_index("Unnamed: 0").dropna()
            genomics = np.log(genomics+0.1)
            if i==0:
                self.dataframe = dataframe
                self.genomics = genomics
            else:
                self.dataframe = pd.concat([self.dataframe, dataframe], ignore_index=True)
                self.genomics = pd.concat([self.genomics, genomics], ignore_index=True)

        #{'pAdnL', 'pOvaR', 'pMes1', 'pOth', 'pTubL', 'pPer', 'pAdnR', 'pTubL1', 'pOva', 'pTubR', 'p2Ome2', 'pPer2', 'pVag', 'pLNR', 'pUte1',
        # 'pPerR1', 'pOvaL1', 'pOvaL', 'p2Oth', 'pPer ', 'pTub', 'pOme2', 'p0Ome', 'pUte2', 'pOva2', 'pMes', 'pOme ', 'pBow', 'pOme1', 'pOth2',
        # 'pAdnR1', 'pOth1', 'p2Ome1', 'pOme', 'p2Per1', 'pPer3', 'pOvaR1', 'pPerL ', 'pUte', 'pOme3', 'pAndL', 'pTub2', 'pPer1'}
        # self.pt_files_path = pt_files_path
        self.max_patches = max_patches
        self.sample = sample
        self.n_bins = n_bins
        # self.label_name = label_name
        # self.censorships_name = censorships_name
        self.eps = eps
        # self._filter_by_tissue_type()
        self._compute_patient_dict()
        self._compute_patient_df()
        if self.task_type == "Survival":
            self._compute_labels()
        else:
            self.patient_df["label"] = self.patient_df["Treatment_Response"]
        print("Dataset loaded with {} slides and {} patients".format(len(self.dataframe), len(self.patient_df)))


    def _compute_patient_dict(self):
        self.patient_list = list(self.dataframe[self.case_id_name].unique())
        self.patient_dict = {patient: list(self.dataframe[self.dataframe[self.case_id_name] == patient][self.slide_id_name]) for patient in self.patient_list}

    def _compute_patient_df(self):
        self.patient_df = self.dataframe.drop_duplicates(subset=self.case_id_name)
        self.patient_df = self.patient_df.reset_index(drop=True)
        self.patient_df = self.patient_df.set_index(self.case_id_name, drop=False)

    def get_train_test_val_splits(self, train_size=0.7, val_size=0.15, test_size=0.15, random_state=42):
        np.random.seed(random_state)
        patients = np.array(self.patient_list)
        np.random.shuffle(patients)
        n = len(patients)
        train_end = int(n * train_size)
        val_end = int(n * (train_size + val_size))
        train_patients = patients[:train_end]
        val_patients = patients[train_end:val_end]
        test_patients = patients[val_end:]

        train_patients_idx = pd.Index(train_patients)
        val_patients_idx = pd.Index(val_patients)
        test_patients_idx = pd.Index(test_patients)
        # for name in self.genomics.columns.tolist():
        #     scaler  = StandardScaler()
        #     self.genomics.loc[train_patients_idx, name] = scaler.fit_transform(self.genomics.loc[train_patients_idx, name].values.reshape(-1,1)).ravel()
        #     self.genomics.loc[val_patients_idx, name]   = scaler.transform(self.genomics.loc[val_patients_idx, name].values.reshape(-1,1)).ravel()
        #     self.genomics.loc[test_patients_idx, name]  = scaler.transform(self.genomics.loc[test_patients_idx, name].values.reshape(-1,1)).ravel()

        self.normalized_genomics = deepcopy(self.genomics)
        X_train = self.normalized_genomics.loc[train_patients_idx, :]
        X_val = self.normalized_genomics.loc[val_patients_idx, :]
        X_test = self.normalized_genomics.loc[test_patients_idx, :]

        scaler = StandardScaler()
        scaler.fit(X_train)  # fit on train set

        # Transform entire subsets of the copied DataFrame
        self.normalized_genomics.loc[train_patients_idx, :] = scaler.transform(X_train)
        self.normalized_genomics.loc[val_patients_idx, :] = scaler.transform(X_val)
        self.normalized_genomics.loc[test_patients_idx, :] = scaler.transform(X_test)

        # train_indices = [i for i, patient in enumerate(self.patient_list) if patient in train_patients]
        # val_indices = [i for i, patient in enumerate(self.patient_list) if patient in val_patients]
        # test_indices = [i for i, patient in enumerate(self.patient_list) if patient in test_patients]
        print("Train: {}, Val: {}, Test: {}".format(len(train_patients), len(val_patients), len(test_patients)))
        assert len(train_patients) + len(val_patients) + len(test_patients) == len(self.patient_list)
        return train_patients, val_patients, test_patients


    def _compute_labels(self):
        uncensored_df = self.patient_df[self.patient_df["censorship"] == 0]
        disc_labels, q_bins = pd.qcut(uncensored_df["time"], q=self.n_bins, retbins=True, labels=False, duplicates='drop')
        q_bins[-1] = self.patient_df["time"].max() + self.eps
        q_bins[0] = self.patient_df["time"].min() - self.eps

        # assign patients to different bins according to their months' quantiles (on all data)
        # cut will choose bins so that the values of bins are evenly spaced. Each bin may have different frequncies
        disc_labels, q_bins = pd.cut(self.patient_df["time"], bins=q_bins, retbins=True, labels=False, right=False, include_lowest=True)
        self.patient_df.insert(2, 'label', disc_labels.values.astype(int))
        self.bins = q_bins

    def _load_wsi_embs_from_path(self, dataset_name, slide_names):
            """
            Load all the patch embeddings from a list a slide IDs.

            Args:
                - self
                - slide_names : List

            Returns:
                - patch_features : torch.Tensor
                - mask : torch.Tensor

            """
            patch_features = []
            pt_files_path = self.datasets[dataset_name].pt_files_path
            # load all slide_names corresponding for the patient
            for slide_id in slide_names:
                if self.load_slides_in_RAM:
                    if slide_id in self.slides_cache:
                        wsi_bag = self.slides_cache[slide_id]
                    else:
                        wsi_path = os.path.join(pt_files_path, '{}.pt'.format(slide_id))
                        wsi_bag = torch.load(wsi_path, weights_only=True)
                        self.slides_cache[slide_id] = wsi_bag
                else:
                    wsi_path = os.path.join(pt_files_path, '{}.pt'.format(slide_id))
                    wsi_bag = torch.load(wsi_path, weights_only=True) # changed to True due to python warning
                patch_features.append(wsi_bag)
            patch_features = torch.cat(patch_features, dim=0)
            # print("patch_features.shape[0]: ", patch_features.shape[0])

            if self.sample:
                max_patches = self.max_patches

                n_samples = min(patch_features.shape[0], max_patches)
                idx = np.sort(np.random.choice(patch_features.shape[0], n_samples, replace=False))
                patch_features = patch_features[idx, :]


                # make a mask
                if n_samples == max_patches:
                    # sampled the max num patches, so keep all of them
                    mask = torch.zeros([max_patches])
                else:
                    # sampled fewer than max, so zero pad and add mask
                    original = patch_features.shape[0]
                    how_many_to_add = max_patches - original
                    zeros = torch.zeros([how_many_to_add, patch_features.shape[1]])
                    patch_features = torch.concat([patch_features, zeros], dim=0)
                    mask = torch.concat([torch.zeros([original]), torch.ones([how_many_to_add])])

            else:
                mask = torch.zeros([patch_features.shape[0]])

            return patch_features, mask

    def set_sample(self, sample):
        self.sample = sample

    def __getitem__(self, index):
        # Retrieve data from the dataframe based on the index
        row  = self.patient_df.loc[index]
        genomics = torch.tensor(self.normalized_genomics.loc[index].values, dtype=torch.float32)
        dataset_name = row["dataset_name"]
        tissue_type_filter = self.datasets[dataset_name].tissue_type_filter
        slide_list = self.patient_dict[row[self.case_id_name]]
        patch_features, mask = self._load_wsi_embs_from_path(dataset_name, slide_list)
        label = row['label']
        if self.task_type == "Survival":
            censorship = row["censorship"]
            time = row["time"]
            label_names = ["time"]
        else:
            censorship = torch.tensor(0)
            time = torch.tensor(0)
            label_names = ["treatment_response"]


        data = {
                'input':{
                            'patch_features': patch_features,
                            'mask': mask,
                            'genomics':genomics
                        },
                'label': label,
                'censorship': censorship,
                'original_event_time': time,
                'label_names': label_names,
                'patient_id': row[self.case_id_name],
                'dataset_name': dataset_name,
            }
        return data

    def __len__(self):
        # Return the total number of samples in the dataset
        return len(self.patient_df)

# %% [markdown]
# ### Multimodal ABMIL

# %%
class ABMIL_Multimodal(nn.Module):
    def __init__(self,
                     input_dim=1024,
                     genomics_input_dim = 19962,
                     inner_dim=64,
                     output_dim=4,
                     use_layernorm=False,
                     input_modalities = ["WSI", "Genomics"],
                     genomics_dropout = 0.5,
                     dropout=0.0,
                ):
        super(ABMIL_Multimodal,self).__init__()

        self.inner_proj = nn.Linear(input_dim,inner_dim)
        self.output_dim = output_dim
        self.device="cuda" if torch.cuda.is_available() else "cpu"
        self.input_modalities = input_modalities
        self.use_layernorm = use_layernorm
        self.dropout = nn.Dropout(dropout)
        if self.use_layernorm:
            self.layernorm = nn.LayerNorm(inner_dim)
        self.attention_V = nn.Linear(inner_dim, inner_dim)
        self.attention_U = nn.Linear(inner_dim, inner_dim)
        self.sigmoid = nn.Sigmoid()
        self.attention_weights = nn.Linear(inner_dim, 1)

        self.genomics_dropout = nn.Dropout(genomics_dropout)
        self.fc_genomics = nn.Sequential(
                                            nn.Linear(genomics_input_dim, inner_dim),
                                            nn.ReLU(),
                                            nn.Linear(inner_dim, inner_dim),
                                        )

        # Output layer
        final_layer_input_dim = 0
        if "WSI" in input_modalities:
            final_layer_input_dim += inner_dim
        if "Genomics" in input_modalities:
            final_layer_input_dim += inner_dim

        self.output_layer = nn.Linear(final_layer_input_dim, output_dim)

    def forward(self, data):
        # Extract patch features
        if "WSI" in self.input_modalities:
            x = data['patch_features']  # x is a dictionary with key 'patch_features'
            mask = data['mask']
            x = x[~mask.bool()].unsqueeze(0)
            x = self.inner_proj(x)

            if self.use_layernorm:
                x = self.layernorm(x)

            # Apply attention mechanism
            V = torch.tanh(self.attention_V(x))  # Shape: (batch_size, num_patches, inner_dim)
            U = self.sigmoid(self.attention_U(x))  # Shape: (batch_size, num_patches, inner_dim)

            # Compute attention scores
            attn_scores = self.attention_weights(V * U)  # Shape: (batch_size, num_patches, 1)
            attn_scores = torch.softmax(attn_scores, dim=1)  # Shape: (batch_size, num_patches, 1)

            # Weighted sum of patch features
            weighted_sum = torch.sum(attn_scores * x, dim=1)  # Shape: (batch_size, inner_dim)
            weighted_sum = self.dropout(weighted_sum)

            # Final WSI embedding
            wsi_embedding = weighted_sum

        if "Genomics" in self.input_modalities:
            genomics = data["genomics"]
            genomics = self.genomics_dropout(genomics)
            # Final Genomic embedding
            genomics_embedding = self.fc_genomics(genomics)

        if "WSI" in self.input_modalities and "Genomics" in self.input_modalities:
            x = torch.cat([wsi_embedding,genomics_embedding], dim=1)
        elif "WSI" in self.input_modalities:
            x = wsi_embedding
        elif "Genomics" in self.input_modalities:
            x = genomics_embedding

        output = self.output_layer(x)  # Shape: (batch_size, output_dim)

        return output

# %%
import torch.nn as nn

class MCAT_Multimodal(nn.Module):
    def __init__(self, input_dim=1024, genomics_input_dim=19962, inner_dim=64, output_dim=4, num_heads=4,
                 input_modalities=["WSI", "Genomics"], dropout=0.1):
        super(MCAT_Multimodal, self).__init__()
        self.input_modalities = input_modalities

        self.wsi_proj = nn.Linear(input_dim, inner_dim)
        self.genomics_proj = nn.Linear(genomics_input_dim, inner_dim)

        self.cross_attn = nn.MultiheadAttention(embed_dim=inner_dim, num_heads=num_heads, batch_first=True, dropout=dropout)

        self.output_layer = nn.Linear(inner_dim, output_dim)
        self.dropout = nn.Dropout(dropout)
        self.norm = nn.LayerNorm(inner_dim)

    def forward(self, data):
        if "WSI" in self.input_modalities:
            x = data['patch_features']
            mask = data['mask']
            x = x[~mask.bool()].unsqueeze(0)
            wsi_embed = self.wsi_proj(x)

        if "Genomics" in self.input_modalities:
            g = data["genomics"].unsqueeze(1)
            genomics_embed = self.genomics_proj(g)

        attn_output, _ = self.cross_attn(query=wsi_embed, key=genomics_embed, value=genomics_embed)
        fused = self.norm(wsi_embed + attn_output)
        pooled = fused.mean(dim=1)
        out = self.output_layer(self.dropout(pooled))
        return out

# %% [markdown]
# ### Survival Loss (SurvPath)

# %%
class NLLSurvLoss(nn.Module):
    """
    The negative log-likelihood loss function for the discrete time to event model (Zadeh and Schmid, 2020).
    Code borrowed from https://github.com/mahmoodlab/Patch-GCN/blob/master/utils/utils.py
    Parameters
    ----------
    alpha: float
        TODO: document
    eps: float
        Numerical constant; lower bound to avoid taking logs of tiny numbers.
    reduction: str
        Do we sum or average the loss function over the batches. Must be one of ['mean', 'sum']
    """

     """
    Negative Log-Likelihood Loss per modelli di survival analysis in tempo discreto.

    Questa loss è basata sul lavoro di Zadeh e Schmid (2020), ed è progettata per predire
    la distribuzione della sopravvivenza in bin temporali discreti.

    Il modello predice le hazard function (probabilità di morte a ogni bin),
    e la loss misura la probabilità negativa (logaritmica) del percorso osservato.

    Parameters
    ----------
    alpha : float, default=0.0
        Peso tra censurati e non censurati.
        - alpha = 0.0 → considera entrambi
        - alpha = 1.0 → considera solo i non censurati (loss parziale)

    eps : float, default=1e-7
        Costante per stabilità numerica (evita log(0))

    reduction : str, default='sum'
        Come aggregare la loss sul batch:
        - 'sum': somma totale--> restituisce la somma delle loss su tutti i pazienti del batch
        - 'mean': media del batch--> restituisce la media delle loss

    References
    ----------
    Zadeh, S.G. & Schmid, M. (2020).
    "Bias in Cross-Entropy-Based Training of Deep Survival Networks".
    IEEE Transactions on Pattern Analysis and Machine Intelligence.
    https://ieeexplore.ieee.org/document/9098975
    """


    def __init__(self, alpha=0.0, eps=1e-7, reduction='sum'):
        super().__init__()
        self.alpha = alpha
        self.eps = eps
        self.reduction = reduction

    def __call__(self, h, y, t, c):
        """
        Parameters
        ----------
        h: (n_batches, n_classes)
            The neural network output discrete survival predictions such that hazards = sigmoid(h).
        y_c: (n_batches, 2) or (n_batches, 3)
            The true time bin label (first column) and censorship indicator (second column).
        """

        return nll_loss(h=h, y=y, c=c,
                        alpha=self.alpha, eps=self.eps,
                        reduction=self.reduction)


# TODO: document better and clean up
def nll_loss(h, y, c, alpha=0.0, eps=1e-7, reduction='sum'):
    """
    The negative log-likelihood loss function for the discrete time to event model (Zadeh and Schmid, 2020).
    Code borrowed from https://github.com/mahmoodlab/Patch-GCN/blob/master/utils/utils.py
    Parameters
    ----------
    h: (n_batches, n_classes)
        The neural network output discrete survival predictions such that hazards = sigmoid(h).
    y: (n_batches, 1)
        The true time bin index label.
    c: (n_batches, 1)
        The censoring status indicator.
    alpha: float
        The weight on uncensored loss
    eps: float
        Numerical constant; lower bound to avoid taking logs of tiny numbers.
    reduction: str
        Do we sum or average the loss function over the batches. Must be one of ['mean', 'sum']
    References
    ----------
    Zadeh, S.G. and Schmid, M., 2020. Bias in cross-entropy-based training of deep survival networks. IEEE transactions on pattern analysis and machine intelligence.
    """
    # print("h shape", h.shape)

    # make sure these are ints
    y = y.type(torch.int64)
    c = c.type(torch.int64)

    hazards = torch.sigmoid(h)
    # print("hazards shape", hazards.shape)

    S = torch.cumprod(1 - hazards, dim=1)
    # print("S.shape", S.shape, S)

    S_padded = torch.cat([torch.ones_like(c), S], 1)
    # S(-1) = 0, all patients are alive from (-inf, 0) by definition
    # after padding, S(0) = S[1], S(1) = S[2], etc, h(0) = h[0]
    # hazards[y] = hazards(1)
    # S[1] = S(1)
    # TODO: document and check

    # print("S_padded.shape", S_padded.shape, S_padded)


    # TODO: document/better naming
    s_prev = torch.gather(S_padded, dim=1, index=y).clamp(min=eps)
    h_this = torch.gather(hazards, dim=1, index=y).clamp(min=eps)
    s_this = torch.gather(S_padded, dim=1, index=y+1).clamp(min=eps)
    # print('s_prev.s_prev', s_prev.shape, s_prev)
    # print('h_this.shape', h_this.shape, h_this)
    # print('s_this.shape', s_this.shape, s_this)

    # c = 1 means censored. Weight 0 in this case
    uncensored_loss = -(1 - c) * (torch.log(s_prev) + torch.log(h_this))
    censored_loss = - c * torch.log(s_this)


    # print('uncensored_loss.shape', uncensored_loss.shape)
    # print('censored_loss.shape', censored_loss.shape)

    neg_l = censored_loss + uncensored_loss
    if alpha is not None:
        loss = (1 - alpha) * neg_l + alpha * uncensored_loss

    if reduction == 'mean':
        loss = loss.mean()
    elif reduction == 'sum':
        loss = loss.sum()
    else:
        raise ValueError("Bad input for reduction: {}".format(reduction))

    return loss

# %% [markdown]
# ### Select the model and define the hyperparameters

# %%
# Models
# device = "cpu"
device = "cuda"

models = {
    'ABMIL_Multimodal': ABMIL_Multimodal,
}
model_configs = {
    'ABMIL_Multimodal': {
         "input_dim":1024,
         "genomics_input_dim" : 19962,
         "inner_dim":64,
         "output_dim":4,
         "use_layernorm":False,
         "input_modalities" : ["WSI", "Genomics"], # ["WSI", "Genomics"] # ["WSI"] # ["Genomics"]
         "genomics_dropout": 0.5,
         "dropout":0.0,
    },
}

# Istantiate Model
selected_model = "ABMIL_Multimodal"
net = models[selected_model](**model_configs[selected_model])
net = net.to(device)

# Loss
reduction = "mean" # sum or mean
loss_function = NLLSurvLoss(alpha=0.0, eps=1e-7, reduction=reduction)

# Training Parameters
MACHINE_BATCH_SIZE = 1
TARGET_BATCH_SIZE = 8
NUM_ACCUMULATION_STEPS = TARGET_BATCH_SIZE//MACHINE_BATCH_SIZE
EPOCHS = 10
PATIENCE = 7
DEBUG_BATCHES = 4

# Optimizer
LR = 0.001
WEIGHT_DECAY = 0.0001
optimizer = optim.RAdam(
                          net.parameters(),
                          lr=LR,
                          weight_decay=WEIGHT_DECAY,
            )
# Scheduler
scheduler_parameters = {
  "milestones": [],
  "gamma": 0.1
}
scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, **scheduler_parameters)

# %% [markdown]
# # Dataset Creation

# %%
def get_dataloaders(dataset, train_patients, val_patients, test_patients, data_loader_config):
    mask = np.isin(train_patients, dataset.patient_df.index)
    # Filter the array to keep only elements in df.index
    filtered_train_patients = train_patients[mask]
    if len(filtered_train_patients) != len(train_patients):
        print("Some train patients are not in the dataset: ", set(train_patients) - set(filtered_train_patients))
    prefetch_factor = 4
    if data_loader_config.num_workers == 0:
        prefetch_factor = None
    train_dataloader = DataLoader(
                                Subset(dataset, filtered_train_patients),
                                batch_size=data_loader_config.batch_size,
                                shuffle=True,
                                drop_last=True,
                                pin_memory=True,
                                num_workers=data_loader_config.num_workers,
                                prefetch_factor=prefetch_factor
                            )
    if val_patients is not None:
        mask = np.isin(val_patients, dataset.patient_df.index)
        filtered_val_patients = val_patients[mask]
        if len(filtered_val_patients) != len(val_patients):
            print("Some val patients are not in the dataset: ", set(val_patients) - set(filtered_val_patients))
        batch_size = data_loader_config.batch_size
        if data_loader_config.test_sample == False:
            batch_size = 1
        val_dataloader = DataLoader(
                                        Subset(dataset, filtered_val_patients),
                                        batch_size=batch_size,
                                        shuffle=False,
                                        drop_last=False,
                                        pin_memory=True,
                                        num_workers=data_loader_config.num_workers,
                                        prefetch_factor=prefetch_factor,
                                )
    else:
        val_dataloader = None
    if test_patients is not None:
        mask = np.isin(test_patients, dataset.patient_df.index)
        filtered_test_patients = test_patients[mask]
        if len(filtered_test_patients) != len(test_patients):
            print("Some test patients are not in the dataset: ", set(test_patients) - set(filtered_test_patients))
        batch_size = data_loader_config.batch_size
        if data_loader_config.test_sample == False:
            batch_size = 1
        test_dataloader = DataLoader(
                                        Subset(dataset, filtered_test_patients),
                                        batch_size=batch_size,
                                        shuffle=False,
                                        drop_last=False,
                                        pin_memory=True,
                                        num_workers=data_loader_config.num_workers,
                                        prefetch_factor=prefetch_factor,
                                    )
    else:
        test_dataloader = None
    return train_dataloader, val_dataloader, test_dataloader

# %%
data_loader_config = {
  "datasets_configs": [TCGA_BRCA_dataset_config],
  "task_type": "Survival",
  "max_patches": 4096,
  "batch_size": MACHINE_BATCH_SIZE,
  "real_batch_size": TARGET_BATCH_SIZE,
  "n_bins": 4,
  "sample": True,        # sample patches during train
  "test_sample": False,   # use all available patches during testing
  "load_slides_in_RAM": False,  # load in RAM patches for increasing data loading speed
  "label_name": "FUT",
  "censorships_name": "Survival",
  "eps": 0.000001,
  "num_workers": 1,
  "train_size": 0.7,
  "val_size": 0.15,
  "test_size": 0.15,
  "random_state": 42,
}

data_loader_config = Munch.fromDict(data_loader_config)

# %%
dataset = Multimodal_WSI_Genomic_Dataset(
                        datasets_configs=data_loader_config.datasets_configs,
                        task_type=data_loader_config.task_type,
                        max_patches=data_loader_config.max_patches,
                        n_bins=data_loader_config.n_bins,
                        eps=data_loader_config.eps,
                        sample=data_loader_config.sample,
                        load_slides_in_RAM=data_loader_config.load_slides_in_RAM,
                    )

# %%
# GET INDICES FOR TRAIN, VALIDATION, AND TEST SETS
train_patients, val_patients, test_patients = dataset.get_train_test_val_splits(
                                                                                train_size=data_loader_config.train_size,
                                                                                val_size=data_loader_config.val_size,
                                                                                test_size=data_loader_config.test_size,
                                                                                random_state=data_loader_config.random_state
                                                                            )
train_dataloader, val_dataloader, test_dataloader = get_dataloaders(
                                                                    dataset=dataset,
                                                                    train_patients=train_patients,
                                                                    val_patients=val_patients,
                                                                    test_patients=test_patients,
                                                                    data_loader_config=data_loader_config
                                                                    )

# %% [markdown]
# ### Utility

# %%
def __reload_net__(path, device='cuda'):
    if device == 'cuda':
        print(f'\nRestoring model weigths from: {path}')
        return torch.load(path)
    else:
        print(f'\nRestoring model weigths from: {path}')
        return torch.load(path, map_location=torch.device('cpu'))

# %%
def calculate_risk(h):
    r"""
    Take the logits of the model and calculate the risk for the patient

    Args:
        - h : torch.Tensor

    Returns:
        - risk : torch.Tensor

    """
    hazards = torch.sigmoid(h)
    survival = torch.cumprod(1 - hazards, dim=1)
    risk = -torch.sum(survival, dim=1).detach().cpu().numpy()
    return risk, survival.detach().cpu().numpy()

def initialize_metrics_dict(task_type="Survival"):
    log_dict = {}
    if task_type == "Survival":
        log_dict["all_risk_scores"] = []
        log_dict["all_censorships"] = []
        log_dict["all_event_times"] = []
        log_dict["all_original_event_times"] = []
        log_dict["survival_predictions"] = []
    elif task_type == "Treatment_Response":
        log_dict["all_labels"] = []
        log_dict["treatment_response_predictions"] = []
        log_dict["treatment_response_logits"] = []
    else:
        raise Exception(f"{task_type} is not supported!")
    log_dict["patient_ids"] = []
    log_dict["dataset_name"] = []
    return log_dict

def compute_metrics_dict(log_dict):
    metrics_dict = {}
    all_risk_scores = np.array(log_dict["all_risk_scores"])
    all_censorships = np.array(log_dict["all_censorships"])
    all_event_times = np.array(log_dict["all_event_times"])
    c_index = concordance_index_censored((1-all_censorships).astype(bool), all_event_times, all_risk_scores, tied_tol=1e-08)[0]
    metrics_dict["c-index"] = c_index
    return metrics_dict

def compute_metrics(log_df, task_type="Survival", device="cuda"):
    if task_type == "Survival":
        all_risk_scores = log_df["all_risk_scores"].values
        all_censorships = log_df["all_censorships"].values
        all_event_times = log_df["all_event_times"].values
        outputs = log_df["survival_predictions"].values
        c_index = concordance_index_censored((1-all_censorships).astype(bool), all_event_times, all_risk_scores, tied_tol=1e-08)[0]
        loss = loss_function(torch.tensor(outputs.tolist()), torch.tensor(all_event_times).unsqueeze(-1), None, torch.tensor(all_censorships).unsqueeze(-1))
        metrics_dict = {"c-index": c_index, "Loss": loss}
    elif task_type == "Treatment_Response":
        all_labels = log_df["all_labels"].values
        all_predictions = log_df["treatment_response_predictions"].values
        all_logits = torch.tensor(log_df["treatment_response_logits"].tolist())
        # Calculate AUC
        logits_for_auc = torch.softmax(all_logits, dim=1).numpy()[:, 1]
        auc = roc_auc_score(all_labels, logits_for_auc)
        f1 = f1_score(all_labels, all_predictions, average='macro')
        accuracy = np.mean(all_labels == all_predictions)
        # Calculate loss
        all_logits = all_logits.to(device)
        all_labels = torch.tensor(all_labels).long().to(device)
        loss = loss_function(all_logits, all_labels)
        metrics_dict = {"AUC": auc, "Loss": loss, "Accuracy": accuracy, "F1-Score": f1}
    else:
        raise Exception(f"{task_type} is not supported!")
    return metrics_dict

def compute_metrics_df(log_df, task_type="Survival"):
    metrics_dict = {}
    curr_metrics_dict = compute_metrics(log_df, task_type)
    metrics_dict.update(curr_metrics_dict)

    dataset_names = log_df["dataset_name"].unique()
    for dataset in dataset_names:
        dataset_df = log_df[log_df["dataset_name"]==dataset]
        curr_metrics_dict = compute_metrics(dataset_df, task_type)
        for key, value in curr_metrics_dict.items():
            metrics_dict[f"{dataset}_{key}"] = value
            metrics_dict[f"{dataset}_{key}"] = value

    metrics_dict = {k: v.item() if isinstance(v, torch.Tensor) else v for k, v in metrics_dict.items()}
    return metrics_dict

# %%
def step(net, batch, log_dict, task_type="Survival", device="cuda"):
    batch_data = batch['input']
    labels = batch['label'] #  check this casting
    batch_data = {key: value.to(device) if isinstance(value, torch.Tensor) else value for key, value in batch_data.items()}
    labels = labels.to(device)

    if len(labels.shape) == 1:
        labels = labels.reshape(-1,1)

    outputs = net(batch_data)

    if task_type == "Survival":
        censorships = batch['censorship'] #  check this casting
        censorships = censorships.to(device)
        if len(censorships.shape) == 1:
            censorships = censorships.reshape(-1,1)
        risk, survival = calculate_risk(outputs) # output.detach()?
        log_dict["all_risk_scores"]+=(risk.flatten().tolist())
        log_dict["all_censorships"]+=(censorships.detach().view(-1).tolist())
        log_dict["all_event_times"]+=(labels.detach().view(-1).tolist())
        log_dict["all_original_event_times"]+=(batch["original_event_time"].detach().view(-1).tolist())
        log_dict["survival_predictions"] += outputs.detach().tolist()
        if len(risk.shape) == 1:
            risk = risk.reshape(-1,1)
    elif task_type == "Treatment_Response":
        censorships = None
        treatment_response_predictions = torch.argmax(outputs.detach().cpu(), dim=1).float()
        log_dict["treatment_response_predictions"] += treatment_response_predictions.numpy().tolist()
        log_dict["treatment_response_logits"] += outputs.detach().cpu().numpy().tolist()
        log_dict["all_labels"] += labels.detach().cpu().numpy().flatten().tolist()
    else:
        raise Exception(f"{task_type} is not supported!")

    log_dict["patient_ids"]+=(batch['patient_id'])
    log_dict["dataset_name"]+=(batch['dataset_name'])
    return outputs, labels, censorships, log_dict

# %%
def train(
            net,
            train_dataloader,
            eval_dataloader=None,
            test_dataloader=None,
            task_type="Survival",
            checkpoint="nn_model.pt",
            device="cuda",
            debug=False,
            path=".",
            kfold="",
            best_model_criterion="highest"
):
    cudnn.benchmark = False
    trainLoss = []
    validationLoss = []
    testLoss = []
    lowest_val_loss = np.inf
    highest_val_metric = 0
    STOP = False
    df_fold_suffix = f"_{kfold}"
    log_fold_string = f"/{kfold}"

    for epoch in range(EPOCHS):
        if STOP:
            print(f'\nSTOPPED at epoch {epoch}')
            break
        if kfold != "":
            print(f'\nStarting training for {kfold}')
        print('\nStarting epoch {}/{}, LR = {}'.format(epoch + 1, EPOCHS, scheduler.get_last_lr()))
        tloss = []

        batch_numb = 0
        log_dict = {}
        net.train()
        train_dataloader.dataset.dataset.set_sample(data_loader_config.sample)
        for idx, batch in tqdm(enumerate(train_dataloader)):
            if debug and batch_numb == DEBUG_BATCHES:
                print("DEBUG_BATCHES value reached")
                break
            if idx == 0:
                log_dict = initialize_metrics_dict(task_type)

            outputs, labels, censorships, log_dict = step(net, batch, log_dict, task_type, device)

            if MACHINE_BATCH_SIZE <= TARGET_BATCH_SIZE:
                if task_type == "Survival":
                    loss = loss_function(outputs, labels, None, censorships)
                elif task_type == "Treatment_Response":
                    loss = loss_function(outputs, labels.squeeze(1))
                else:
                    raise Exception(f"{task_type} is not supported!")

                loss = loss / NUM_ACCUMULATION_STEPS
                tloss.append(loss.item()*NUM_ACCUMULATION_STEPS)
                loss.backward()
                if ((idx + 1) % NUM_ACCUMULATION_STEPS == 0):
                    torch.nn.utils.clip_grad_norm_(net.parameters(), max_norm=1)
                    optimizer.step()
                    optimizer.zero_grad()
            else:
                    raise Exception("MACHINE_BATCH_SIZE MUST BE EQUAL OR SMALLER THAN TARGET_BATCH_SIZE!!!")
            batch_numb += 1

        scheduler.step()
        tloss = np.array(tloss)
        tloss = np.mean(tloss)
        trainLoss.append(tloss)
        train_df = pd.DataFrame(log_dict)
        train_df.to_hdf(f"{path}/train_df{df_fold_suffix}.h5", key="df", mode="w")
        train_metrics_dict = compute_metrics_df(train_df, task_type)
        train_metrics_df = pd.DataFrame(train_metrics_dict, index=[0])
        train_metrics_df.to_csv(f"{path}/train_metrics{df_fold_suffix}.csv")
        # KaplanMeier_plot(log_dict, train_dataloader.dataset.dataset.bins.astype(int))
        # predTime_vs_actualTime_confusionMatrix_plot(log_dict)
        to_log = {
                f'Epoch': epoch + 1,
                f'LR': optimizer.param_groups[0]['lr'],
                # f'Train/Loss': tloss,
                # f'Train/c-index': train_metrics_dict["c-index"],
                # f'Valid/Loss': vloss,
                # f'Valid/c-index': val_metrics_dict["c-index"],
                }
        for key, value in train_metrics_dict.items():
            to_log[f'Train{log_fold_string}/{key}'] = value

        train_dataloader.dataset.dataset.set_sample(data_loader_config.test_sample)
        if eval_dataloader is not None:
            net.eval()
            vloss = []
            vlossWeights = []
            batch_numb = 0
            with torch.inference_mode():
                for idx, batch in tqdm(enumerate(eval_dataloader)):
                    if debug and batch_numb == DEBUG_BATCHES:
                        break
                    if idx == 0:
                        log_dict = initialize_metrics_dict(task_type)
                    outputs, labels, censorships, log_dict = step(net, batch, log_dict, task_type, device)
                    if task_type == "Survival":
                        loss = loss_function(outputs, labels, None, censorships)
                    elif task_type == "Treatment_Response":
                        loss = loss_function(outputs, labels.squeeze(1))
                    else:
                        raise Exception(f"{task_type} is not supported!")
                    if MACHINE_BATCH_SIZE <= TARGET_BATCH_SIZE:
                        vloss.append(loss.detach().item())
                    vlossWeights.append(batch["label"].size(dim=0))
                    batch_numb += 1
            vloss = np.array(vloss)
            vloss = np.average(vloss, weights=vlossWeights)
            # vloss = np.sum(vloss)
            validationLoss.append(vloss)
            val_df = pd.DataFrame(log_dict)
            val_df.to_hdf(f"{path}/val_df{df_fold_suffix}.h5", key="df", mode="w")
            val_metrics_dict = compute_metrics_df(val_df, task_type)
            val_metrics_df = pd.DataFrame(val_metrics_dict, index=[0])
            val_metrics_df.to_csv(f"{path}/val_metrics{df_fold_suffix}.csv")
            for key, value in val_metrics_dict.items():
                to_log[f'Valid{log_fold_string}/{key}'] = value
            vmetric = val_metrics_df["c-index"].values[0]


        if test_dataloader is not None:
            net.eval()
            ttloss = []
            ttlossWeights = []
            batch_numb = 0
            with torch.inference_mode():
                for idx, batch in tqdm(enumerate(test_dataloader)):
                    if debug and batch_numb == DEBUG_BATCHES:
                        break
                    if idx == 0:
                        log_dict = initialize_metrics_dict(task_type)
                    outputs, labels, censorships, log_dict = step(net, batch, log_dict, task_type, device)
                    if task_type == "Survival":
                        loss = loss_function(outputs, labels, None, censorships)
                    elif task_type == "Treatment_Response":
                        loss = loss_function(outputs, labels.squeeze(1))
                    else:
                        raise Exception(f"{task_type} is not supported!")
                    if MACHINE_BATCH_SIZE <= TARGET_BATCH_SIZE:
                        ttloss.append(loss.item())
                    else:
                        ttloss.append(loss.detach().mean().item())
                    ttlossWeights.append(batch["label"].size(dim=0))
                    batch_numb += 1
            ttloss = np.array(ttloss)
            ttloss = np.average(ttloss, weights=ttlossWeights)
            # ttloss = np.sum(ttloss)
            testLoss.append(ttloss)
            test_df = pd.DataFrame(log_dict)
            test_df.to_hdf(f"{path}/test_df{df_fold_suffix}.h5", key="df", mode="w")
            test_metrics_dict = compute_metrics_df(test_df, task_type)
            test_metrics_df = pd.DataFrame(test_metrics_dict, index=[0])
            test_metrics_df.to_csv(f"{path}/test_metrics{df_fold_suffix}.csv")

            test_log = {
                # f'Test/Loss': ttloss,
                # f'Test/c-index': test_metrics_dict["c-index"],
                }
            for key, value in test_metrics_dict.items():
                test_log[f'Test{log_fold_string}/{key}'] = value

            to_log.update(test_log)
            # if task_type == "Treatment_Response":
            #     plot_to_log = {
            #         f"Train{log_fold_string}/Confusion_Matrix": wandb.Image(train_confusion_matrix),
            #     }
            #     if eval_dataloader is not None:
            #         plot_to_log[f"Valid{log_fold_string}/Confusion_Matrix"] = wandb.Image(val_confusion_matrix)
            #     if test_dataloader is not None:
            #         plot_to_log[f"Test{log_fold_string}/Confusion_Matrix"] = wandb.Image(test_confusion_matrix)
            #     to_log.update(plot_to_log)


        # wandb.log(to_log)
        print(f"EPOCH {epoch+1}\n")
        for k, v in to_log.items():
            pad = ' '.join(['' for _ in range(25-len(k))])
            print(f"{k}:{pad} {v}", flush=True)


        # Early stopping
        if eval_dataloader is not None:
            if best_model_criterion == "lowest":
                if vloss < lowest_val_loss:
                    lowest_val_loss = vloss
                    patience_counter = 0
                    lowest_val_loss_epoch = epoch + 1
                    print(
                        f"############################################ New lowest_val_loss reached: {lowest_val_loss} #########################")
                    if kfold != "":
                        checkpoint_splitted = checkpoint.split(".")
                        checkpoint = f"{checkpoint_splitted[0]}{df_fold_suffix}.pt"
                    torch.save(net, checkpoint)
                    # wandb.run.summary["Lowest_Validation_Loss/Epoch"] = lowest_val_loss_epoch
                    # wandb.run.summary["Lowest_Validation_Loss/Validation_Loss"] = lowest_val_loss
                    # wandb.run.summary["Lowest_Validation_Loss/Validation_c-index"] = val_metrics_dict["c-index"],
                    for key, value in val_metrics_dict.items():
                        # wandb.run.summary[f"Lowest_Validation_Loss/Valid{log_fold_string}/{key}"] = value
                        print(f"Lowest_Validation_Loss/Valid{log_fold_string}/{key}: {value}")
                    # # wandb.run.summary["Lowest_Validation_Loss/Validation_KM"] = val_metrics_dict["KM"],
                    train_df.to_hdf(f"{path}/best_train_df{df_fold_suffix}.h5", key="df", mode="w")
                    train_metrics_df.to_csv(f"{path}/best_train_metrics{df_fold_suffix}.csv")
                    val_df.to_hdf(f"{path}/best_val_df{df_fold_suffix}.h5", key="df", mode="w")
                    val_metrics_df.to_csv(f"{path}/best_val_metrics{df_fold_suffix}.csv")
            elif best_model_criterion == "highest":
                if vmetric > highest_val_metric:
                    highest_val_metric = vmetric
                    patience_counter = 0
                    lowest_val_loss_epoch = epoch + 1
                    print(
                        f"############################################ New highest_val_metric reached: {highest_val_metric} #########################")
                    if kfold != "":
                        checkpoint_splitted = checkpoint.split(".")
                        checkpoint = f"{checkpoint_splitted[0]}{df_fold_suffix}.pt"
                    torch.save(net, checkpoint)
                    # wandb.run.summary["Lowest_Validation_Loss/Epoch"] = lowest_val_loss_epoch
                    # wandb.run.summary["Lowest_Validation_Loss/Validation_Loss"] = lowest_val_loss
                    # wandb.run.summary["Lowest_Validation_Loss/Validation_c-index"] = val_metrics_dict["c-index"],
                    for key, value in val_metrics_dict.items():
                        # wandb.run.summary[f"Lowest_Validation_Loss/Valid{log_fold_string}/{key}"] = value
                        print(f"Lowest_Validation_Loss/Valid{log_fold_string}/{key}: {value}")
                    # # wandb.run.summary["Lowest_Validation_Loss/Validation_KM"] = val_metrics_dict["KM"],
                    train_df.to_hdf(f"{path}/best_train_df{df_fold_suffix}.h5", key="df", mode="w")
                    train_metrics_df.to_csv(f"{path}/best_train_metrics{df_fold_suffix}.csv")
                    val_df.to_hdf(f"{path}/best_val_df{df_fold_suffix}.h5", key="df", mode="w")
                    val_metrics_df.to_csv(f"{path}/best_val_metrics{df_fold_suffix}.csv")
            else:
                raise Exception(f"{best_model_criterion} is not supported!")

            if patience_counter == PATIENCE:
                print(f"End of training phase - Patience threshold reached\nWeights Restored from Lowest val_loss epoch: {lowest_val_loss_epoch}\nlowest_val_loss: {lowest_val_loss}")
                STOP = True
            else:
                patience_counter += 1

# %% [markdown]
# # Train the model!

# %%
print("selected_model: ", selected_model)
train(
      net,
      train_dataloader,
      val_dataloader,
      test_dataloader,
      checkpoint="best_model.pt",
      device=device,
      debug=False,
      best_model_criterion="highest", # highest for highest validation metric, lowest for lowest validation loss
     )

# %%
def KaplanMeier(input_df):
    df = pd.DataFrame({
        "time": input_df['all_original_event_times']/365.0,
        "event": input_df['all_censorships'],
        "risk_score": input_df['all_risk_scores']
    })

    # Step 2: Invert the event indicator if needed
    # If currently event=1 means censored and event=0 means event occurred:
    # KaplanMeierFitter expects 1 for event_occurred and 0 for censored.
    df['event_observed'] = 1 - df['event']

    # Step 3: Categorize the risk_score into two groups
    df['risk_group'] = pd.qcut(df['risk_score'], 2, labels=["Low", "High"])

    # Step 4: Fit the Kaplan-Meier curves for each group
    kmf = KaplanMeierFitter()

    plt.figure(figsize=(10, 6))
    for group in df['risk_group'].unique():
        mask = (df['risk_group'] == group)
        kmf.fit(
            durations=df.loc[mask, 'time'],
            event_observed=df.loc[mask, 'event_observed'],
            label=f"Risk: {group}"
        )
        kmf.plot_survival_function(ci_show=True)

    # Step 5: Perform a log-rank test between the two groups (Low vs High)
    low_mask = (df['risk_group'] == "Low")
    high_mask = (df['risk_group'] == "High")

    results = logrank_test(
        durations_A=df.loc[low_mask, 'time'],
        durations_B=df.loc[high_mask, 'time'],
        event_observed_A=df.loc[low_mask, 'event_observed'],
        event_observed_B=df.loc[high_mask, 'event_observed']
    )

    p_value = results.p_value
    print("Log-rank test p-value:", p_value)

    # Step 6: Customize the plot and include p-value in the title
    plt.title(f"Kaplan-Meier Survival Curves by Risk Group\nLog-rank p-value: {p_value:.4f}")
    plt.xlabel("Time (years)")
    plt.ylabel("Survival Probability")
    plt.legend(title='Risk Group')
    plt.grid(True)
    plt.show()

# %%
def evaluate(net, test_dataloader, task_type="Survival", checkpoint=None, device="cuda", best=False, path=".", kfold=""):
    cudnn.benchmark = False
    print("test")
    df_fold_suffix = f"_{kfold}"
    log_fold_string = f"/{kfold}"
    if best:
        if kfold != "":
            checkpoint_splitted = checkpoint.split(".")
            checkpoint = f"{checkpoint_splitted[0]}{df_fold_suffix}.pt"
        net = torch.load(checkpoint)
        print("\n Evalate best model")
    else:
        net = net
        print("\n Evalate last model")

    net = net.to(device)
    net.eval()
    tloss = []
    tlossWeights = []
    with torch.inference_mode():
        for idx, batch  in enumerate(test_dataloader):
            if idx == 0:
                    log_dict = initialize_metrics_dict(task_type)
            # batch_data = torch.squeeze(batch_data, 0)
            outputs, labels, censorships, log_dict = step(net, batch, log_dict, task_type, device)
            if task_type == "Survival":
                loss = loss_function(outputs, labels, None, censorships)
            elif task_type == "Treatment_Response":
                loss = loss_function(outputs, labels.squeeze(1))
            else:
                    raise Exception(f"{task_type} is not supported!")

            if MACHINE_BATCH_SIZE <= TARGET_BATCH_SIZE:
                tloss.append(loss.item())
            else:
                tloss.append(loss.detach().mean().item())
            tlossWeights.append(batch["label"].size(dim=0))

    tloss = np.array(tloss)
    tloss = np.average(tloss, weights=tlossWeights)
    test_df = pd.DataFrame(log_dict)
    test_metrics_dict = compute_metrics_df(test_df, task_type)

    if best:
        # wandb.run.summary["Lowest_Validation_Loss/Test_Loss"] = tloss
        # wandb.run.summary["Lowest_Validation_Loss/Test_c-index"] = test_metrics_dict["c-index"]
        for key, value in test_metrics_dict.items():
                # wandb.run.summary[f"Lowest_Validation_Loss/Test{log_fold_string}/{key}"] = value
                print(f"Lowest_Validation_Loss/Test{log_fold_string}/{key}: {value}")
        test_df.to_hdf(f"{path}/best_test_df{df_fold_suffix}.h5", key="df", mode="w")
        KaplanMeier(test_df)
        test_metrics_df = pd.DataFrame(test_metrics_dict, index=[0])
        test_metrics_df.to_csv(f"{path}/best_test_metrics{df_fold_suffix}.csv")
        # if task_type == "Treatment_Response":
        #     test_confusion_matrix = accuracy_confusionMatrix_plot(log_dict, test_metrics_df)
    else:
        for key, value in test_metrics_dict.items():
                # wandb.run.summary[f"Last_Epoch_Model/Test{log_fold_string}/{key}"] = value
                print(f"Last_Epoch_Model/Test{log_fold_string}/{key}: {value}")
        test_df.to_hdf(f"{path}/last_epoch_test_df{df_fold_suffix}.h5", key="df", mode="w")
        KaplanMeier(test_df)
        test_metrics_df = pd.DataFrame(test_metrics_dict, index=[0])
        test_metrics_df.to_csv(f"{path}/last_epoch_test_metrics{df_fold_suffix}.csv")
        # if task_type == "Treatment_Response":
        #     test_confusion_matrix = accuracy_confusionMatrix_plot(log_dict, test_metrics_df)

# %% [markdown]
# # Evaluate last and best model!

# %%
evaluate(net, test_dataloader, task_type="Survival", checkpoint=None, device=device, best=False, path=".", kfold="")

# %%
evaluate(net, test_dataloader, task_type="Survival", checkpoint="best_model.pt", device=device, best=True, path=".", kfold="")
